# %% [markdown]
# # Lab 1: EDA
#
# ## Dataset Overview
#
# Today's lab utilizes a subset of the **Carrier On-Time Performance Dataset** ([Kaggle link](https://www.kaggle.com/datasets/mexwell/carrier-on-time-performance-dataset?resource=download)), which originally contains data on 2 million domestic US flights. For this session, we focus specifically on flight data from **2019** to perform **Exploratory Data Analysis (EDA)**.
#
# The link for the data today: [download](https://nuwildcat-my.sharepoint.com/:x:/g/personal/dxk9547_ads_northwestern_edu/IQAfJBZ99jdcTKg2iqSrD6QMAeyclVF_jJ0YE_PJy-eMtnM?e=1HvTQ8)
#
# ## Objectives
#
# The preprocessing and analysis tasks for today's lab include:
#
# - **Renaming columns** to improve readability.
# - **Generating descriptive statistics**, such as mean, standard deviation, and percentiles.
# - **Calculating missing values**, expressed as a percentage for each column.
# - **Visualizing data** using:
#   - **Boxplots** for continuous variables.
#   - **Bar charts** for discrete variables.
# - **Filtering data** to exclude outliers or irrelevant entries.
# - **Creating new features** through transformations, such as:
#   - Logarithmic transformation.
#   - Normalization and standardization.
# - **Computing additional insights**, including:
#   - Total flight counts.
#   - Average flight speeds.
# - **Plotting relationships**, such as arrival delays versus departure times.
# - **Comparing subsets of data**, like flights from specific airports (e.g., SFO vs. LGA).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Change the file location to your saved location
FILE_LOCATION = "airline_2019.csv"

# %%
use_cols = [
    # 29 columns out of 109
    "Year", "Month", "DayofMonth", "DayOfWeek", "DepTime", "CRSDepTime",
    "ArrTime", "CRSArrTime", "Reporting_Airline","Flight_Number_Reporting_Airline", 
    "Tail_Number", "ActualElapsedTime", "CRSElapsedTime", "AirTime", "ArrDelay", "DepDelay", "Origin", "Dest",
    "Distance", "TaxiIn", "TaxiOut", "Cancelled",
    "CancellationCode", "Diverted", "CarrierDelay", "WeatherDelay", "NASDelay", "SecurityDelay",
    "LateAircraftDelay"
]

# %%
df_2019 = pd.read_csv(FILE_LOCATION, usecols = use_cols)

# %%
df_2019.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek Reporting_Airline Tail_Number  \
# 0  2019      6          11          2                9E      N927XJ
# 1  2019      9           2          1                YX      N203JQ
# 2  2019      3          27          3                OH      N582NN
# 3  2019      2          13          3                WN      N491WN
# 4  2019      5           8          3                DL      N922DZ
# 5  2019     11          10          7                OO      N909EV
# 6  2019      4          23          2                DL      N342NB
# 7  2019     12          30          1                AA      N179UW
# 8  2019      9           6          5                OO      N243SY
# 9  2019     11          25          1                NK      N915NK
#
#    Flight_Number_Reporting_Airline Origin Dest  CRSDepTime  ...  Diverted  \
# 0                             3459    ATL  CAE        1950  ...         0
# 1                             6104    JAX  BOS        1204  ...         0
# 2                             5125    CHO  CLT        1605  ...         0
# 3                              172    MSY  FLL        1055  ...         0
# 4                             1416    JAX  ATL        1714  ...         0
# 5                             5050    DEN  PUB        1541  ...         0
# 6                             2583    MSP  JFK        1000  ...         0
# 7                             1320    BOS  CLT        1447  ...         0
# 8                             3977    SEA  SLC        2104  ...         0
# 9                              903    ORD  DFW        2050  ...         0
#
#    CRSElapsedTime  ActualElapsedTime  AirTime  Distance  CarrierDelay  \
# 0            67.0               60.0     35.0       192           0.0
# 1           168.0              169.0    149.0      1010           NaN
# 2            83.0               77.0     52.0       245           NaN
# 3           115.0              109.0     97.0       674           NaN
# 4            81.0               65.0     44.0       270           NaN
# 5            49.0               43.0     26.0       109           NaN
# 6           176.0              149.0    129.0      1029           NaN
# 7           154.0              167.0    132.0       728           NaN
# 8           125.0              116.0     89.0       689           NaN
# 9           156.0              147.0    119.0       801           NaN
#
#    WeatherDelay  NASDelay SecurityDelay  LateAircraftDelay
# 0           0.0       0.0           0.0              214.0
# 1           NaN       NaN           NaN                NaN
# 2           NaN       NaN           NaN                NaN
# 3           NaN       NaN           NaN                NaN
# 4           NaN       NaN           NaN                NaN
# 5           NaN       NaN           NaN                NaN
# 6           NaN       NaN           NaN                NaN
# 7           NaN       NaN           NaN                NaN
# 8           NaN       NaN           NaN                NaN
# 9           NaN       NaN           NaN                NaN
#
# [10 rows x 29 columns]

# %%
print(f'Number of observations in 2019: {df_2019.shape[0]}')
# Out:
# Number of observations in 2019: 76616

# %% [markdown]
# ## Read in the datasets and extract a subset for each

# %%
# rename a a few columns
df_2019.rename(
    columns={
        "Reporting_Airline":"UniqueCarrier", 
        "Flight_Number_Reporting_Airline":"FlightNum", 
        "Tail_Number":"TailNum"
    }, 
    inplace=True
)

# df.rename() method: Original_Name:NewName
# - Snake Case Convention: use underscores (_) to separate words
# - Camel Case/ Pascal Case: capitalize the first letter of each word

# %%
# randomly sample 20k observations and perform analysis on this subset
df_2019 = df_2019.sample(n=20000,random_state=1)

# %% [markdown]
# ## EDA
# ### 1. Quick Profile of Dataset

# %%
# first 5 rows of 2019 data
df_2019.head(5)
# Out:
#        Year  Month  DayofMonth  DayOfWeek UniqueCarrier TailNum  FlightNum  \
# 63489  2019     11           3          7            MQ  N612AE       3525
# 45712  2019      5          21          2            WN  N8310C       1143
# 23037  2019     10           6          7            OO  N196SY       3304
# 53159  2019     10          24          4            MQ  N238NN       3551
# 15357  2019     10          14          1            B6  N804JB        567
#
#       Origin Dest  CRSDepTime  ...  Diverted  CRSElapsedTime  \
# 63489    BMI  ORD        1002  ...         0            60.0
# 45712    BWI  ISP        1805  ...         0            65.0
# 23037    SJC  TUS        1730  ...         0           125.0
# 53159    MDT  ORD         640  ...         0           132.0
# 15357    ATL  FLL        1615  ...         0           114.0
#
#        ActualElapsedTime  AirTime  Distance  CarrierDelay  WeatherDelay  \
# 63489               49.0     32.0       116           4.0           0.0
# 45712               62.0     50.0       220           0.0           0.0
# 23037              122.0    101.0       722           0.0           0.0
# 53159              124.0     99.0       594           NaN           NaN
# 15357               96.0     79.0       581           NaN           NaN
#
#        NASDelay SecurityDelay  LateAircraftDelay
# 63489       0.0           0.0               13.0
# 45712       0.0           0.0               15.0
# 23037       0.0           0.0               22.0
# 53159       NaN           NaN                NaN
# 15357       NaN           NaN                NaN
#
# [5 rows x 29 columns]

# %%
def get_info(pd_frame):
    # generate descriptive statistics (like count, mean, std, min, etc.) for numeric columns
    res = pd_frame.describe().transpose()
    # calculate the missing percentage for each variable
    res['missing_percent'] = [(pd_frame.shape[0] - res.loc[ind, 'count'])/pd_frame.shape[0] for ind in res.index]
    # 
    res['unique_val'] = [len(pd_frame.loc[:,ind].value_counts()) for ind in res.index]
    res['var_type'] = ['Continuous' if res.loc[ind, 'unique_val'] >=100 else 'Categorical' for ind in res.index]
    return res

# %%
df_2019_info = get_info(df_2019)
df_2019_info
# Out:
#                      count         mean          std     min     25%     50%  \
# Year               20000.0  2019.000000     0.000000  2019.0  2019.0  2019.0
# Month              20000.0     6.605000     3.423224     1.0     4.0     7.0
# DayofMonth         20000.0    15.738550     8.755634     1.0     8.0    16.0
# DayOfWeek          20000.0     3.918800     2.002850     1.0     2.0     4.0
# FlightNum          20000.0  2565.617600  1798.927455     1.0  1039.0  2169.0
# CRSDepTime         20000.0  1333.964250   493.976810     5.0   915.0  1325.0
# DepTime            19664.0  1337.476302   509.307628     1.0   915.0  1330.0
# DepDelay           19664.0    11.424837    51.869243   -42.0    -5.0    -2.0
# TaxiOut            19647.0    17.466789     9.884078     3.0    11.0    15.0
# TaxiIn             19629.0     7.791737     6.434550     1.0     4.0     6.0
# CRSArrTime         20000.0  1491.296300   519.685583     1.0  1104.0  1520.0
# ArrTime            19629.0  1467.403179   541.456179     1.0  1049.0  1504.0
# ArrDelay           19591.0     5.941861    53.951863   -68.0   -15.0    -6.0
# Cancelled          20000.0     0.017800     0.132227     0.0     0.0     0.0
# Diverted           20000.0     0.002650     0.051411     0.0     0.0     0.0
# CRSElapsedTime     19999.0   142.189009    72.181319    25.0    90.0   125.0
# ActualElapsedTime  19591.0   137.108519    72.327614    27.0    84.0   120.0
# AirTime            19591.0   111.866980    70.325048    14.0    60.0    94.0
# Distance           20000.0   802.951650   591.733252    41.0   369.0   644.0
# CarrierDelay        3711.0    21.726489    70.497614     0.0     0.0     0.0
# WeatherDelay        3711.0     4.644301    45.987671     0.0     0.0     0.0
# NASDelay            3711.0    17.748585    39.760375     0.0     0.0     3.0
# SecurityDelay       3711.0     0.092697     2.002432     0.0     0.0     0.0
# LateAircraftDelay   3711.0    27.980059    53.417101     0.0     0.0     2.0
#
#                        75%     max  missing_percent  unique_val     var_type
# Year               2019.00  2019.0          0.00000           1  Categorical
# Month                10.00    12.0          0.00000          12  Categorical
# DayofMonth           23.00    31.0          0.00000          31  Categorical
# DayOfWeek             6.00     7.0          0.00000           7  Categorical
# FlightNum          3923.25  7435.0          0.00000        5678   Continuous
# CRSDepTime         1740.00  2359.0          0.00000        1150   Continuous
# DepTime            1750.00  2400.0          0.01680        1244   Continuous
# DepDelay              7.00  1628.0          0.01680         375   Continuous
# TaxiOut              20.00   143.0          0.01765         106   Continuous
# TaxiIn                9.00   174.0          0.01855          78  Categorical
# CRSArrTime         1925.00  2359.0          0.00000        1244   Continuous
# ArrTime            1922.00  2400.0          0.01855        1323   Continuous
# ArrDelay              7.00  1631.0          0.02045         409   Continuous
# Cancelled             0.00     1.0          0.00000           2  Categorical
# Diverted              0.00     1.0          0.00000           2  Categorical
# CRSElapsedTime      172.00   616.0          0.00005         407   Continuous
# ActualElapsedTime   167.00   615.0          0.02045         418   Continuous
# AirTime             140.00   578.0          0.02045         393   Continuous
# Distance           1033.25  5095.0          0.00000        1383   Continuous
# CarrierDelay         17.00  1628.0          0.81445         220   Continuous
# WeatherDelay          0.00  1410.0          0.81445         104   Continuous
# NASDelay             21.00   926.0          0.81445         180   Continuous
# SecurityDelay         0.00    75.0          0.81445          12  Categorical
# LateAircraftDelay    33.00   795.0          0.81445         246   Continuous

# %%
plt.rcParams.update(**{'figure.dpi':150})
plt.style.use('ggplot') # can skip this - plots are more visually appealing with this style

fig,axs = plt.subplots(6,4,figsize=(14,21))

for i,ind in enumerate(df_2019_info.index):
    # 2019 data

    # if the value type is continuous, we will use boxplot
    if df_2019_info.loc[ind, 'var_type'] == 'Continuous':
        sns.boxplot(df_2019,y=ind,ax=axs[i//4, i%4],width=0.5)
        
    # if the value type is discrete, we will use bar chart
    else:
        sns.countplot(data=df_2019,x=ind,color='#1f77b4',ax=axs[i//4, i%4])
    
    axs[i//4, i%4].set_title(ind)

    


fig.tight_layout()

# %%
df_2019_per_missing = (df_2019.isnull().sum()/df_2019.shape[0]).round(2)
df_2019_per_missing[df_2019_per_missing > 0]
# Out:
# DepTime              0.02
# DepDelay             0.02
# TaxiOut              0.02
# TaxiIn               0.02
# ArrTime              0.02
# ArrDelay             0.02
# CancellationCode     0.98
# ActualElapsedTime    0.02
# AirTime              0.02
# CarrierDelay         0.81
# WeatherDelay         0.81
# NASDelay             0.81
# SecurityDelay        0.81
# LateAircraftDelay    0.81
# dtype: float64

# %%
fig,axs = plt.subplots(1,2,figsize=(14,8))

columns = ['DayofMonth','DayOfWeek']

for i,column in enumerate(columns):
    # 2019 data

    _ = sns.countplot(data=df_2019,x=column,color='#1f77b4',ax=axs[i])
    # Alternatively (without seaborn)
    # _ = df_2019[column].value_counts().sort_index().plot(kind='bar',ax=axs[0,i])

    
_ = axs[0].set_title('2019: Day')
_ = axs[1].set_title('2019: Weekday (1=Monday)')

fig.tight_layout()

# %% [markdown]
# ## Bivariate EDA 1: Departure Delay and Arrival Delay

# %%
dt_plot = sns.histplot(df_2019,x='CRSDepTime',bins = 25)
dt_plot.set_title('2019: Scheduled Departure Time',fontsize=12)

fig.tight_layout()

# %%
fig,axs = plt.subplots(1,3,figsize=(16,8))

### Histogram and Scatterplot of Depature Delay and Arrival Delay ###
_ = sns.histplot(df_2019,x='DepDelay',ax=axs[0],bins=25)
_ = axs[0].set_title('2019: Departure Delay, minutes')

_ = sns.histplot(df_2019,x='ArrDelay',ax=axs[1],bins = 25)
_ = axs[1].set_title('2019: Arrival Delay, minutes')

_ = sns.scatterplot(df_2019,x='DepDelay',y='ArrDelay',ax=axs[2])
_ = axs[2].axline((0, 0), slope=1,color='black',linestyle='dashed')
_ = axs[2].set_title('2019')

# %%
# plot of arrival delay vs departure time
fig,ax = plt.subplots(1,1,figsize=(4,4))

_ = sns.scatterplot(df_2019,x='CRSDepTime',y='ArrDelay',ax=ax)
_ = ax.set_title('2019: Arrival Delay vs Scheduled Departure Time',fontsize=12)

# %% [markdown]
# ## Bivariate EDA 2: Distance and Airtimes

# %%
fig,axs = plt.subplots(1,1,figsize=(8,4))

_ = sns.scatterplot(df_2019,x='Distance',y='AirTime')
_ = axs.set_title('2019',fontsize=12)

# %%
# filter airtimes > 500
df_2019.query('AirTime > 500')
# Out:
#        Year  Month  DayofMonth  DayOfWeek UniqueCarrier TailNum  FlightNum  \
# 70547  2019     10          31          4            UA  N69063        362
# 22822  2019      6          24          1            UA  N211UA        202
# 14724  2019      7           7          7            UA  N66051        345
# 73539  2019      7          21          7            UA  N646UA        344
# 75548  2019      6          28          5            HA  N382HA         90
# 64966  2019      5          11          6            UA  N673UA        344
# 38930  2019     12          10          2            UA  N76064        362
# 72684  2019      6          12          3            UA  N210UA        202
# 9770   2019      6           8          6            UA  N774UA        202
#
#       Origin Dest  CRSDepTime  ...  Diverted  CRSElapsedTime  \
# 70547    HNL  EWR        1455  ...         0           560.0
# 22822    ORD  OGG        1020  ...         0           548.0
# 14724    IAD  HNL         850  ...         0           616.0
# 73539    HNL  IAD        1535  ...         0           548.0
# 75548    HNL  BOS        1350  ...         0           600.0
# 64966    HNL  IAD        1535  ...         0           543.0
# 38930    HNL  EWR        1550  ...         0           560.0
# 72684    ORD  OGG        1020  ...         0           548.0
# 9770     ORD  OGG        1020  ...         0           548.0
#
#        ActualElapsedTime  AirTime  Distance  CarrierDelay  WeatherDelay  \
# 70547              560.0    523.0      4962           NaN           NaN
# 22822              569.0    503.0      4184           0.0           0.0
# 14724              615.0    578.0      4817           NaN           NaN
# 73539              533.0    508.0      4817           NaN           NaN
# 75548              577.0    546.0      5095           NaN           NaN
# 64966              565.0    534.0      4817           NaN           NaN
# 38930              574.0    515.0      4962           NaN           NaN
# 72684              532.0    504.0      4184           NaN           NaN
# 9770               550.0    506.0      4184           NaN           NaN
#
#        NASDelay SecurityDelay  LateAircraftDelay
# 70547       NaN           NaN                NaN
# 22822      25.0           0.0                0.0
# 14724       NaN           NaN                NaN
# 73539       NaN           NaN                NaN
# 75548       NaN           NaN                NaN
# 64966       NaN           NaN                NaN
# 38930       NaN           NaN                NaN
# 72684       NaN           NaN                NaN
# 9770        NaN           NaN                NaN
#
# [9 rows x 29 columns]

# %% [markdown]
# # Introduction to Seaborn Plotting Functions
#
# ## 1. sns.boxplot
# ```python
# sns.boxplot(data=your_dataframe, x='categorical_column', y='numerical_column')
# ```
# ### Description:
# Creates a box-and-whisker plot to display the distribution of a numerical variable across categories.
# - **Use case:** Visualizing spread, outliers, and quartiles.
# - **Key Parameters:**
#   - `x` or `y`: Categorical and numerical variables.
#   - `hue`: Optional grouping variable for color-coded subgroups.
#
# ---
#
# ## 2. sns.countplot
# ```python
# sns.countplot(data=your_dataframe, x='categorical_column')
# ```
# ### Description:
# Displays the count of observations for each category in a categorical variable.
# - **Use case:** Summarizing the frequency distribution of categories.
# - **Key Parameters:**
#   - `x` or `y`: Categorical variable to count.
#   - `hue`: Optional for additional grouping.
#
# ---
#
# ## 3. sns.histplot
# ```python
# sns.histplot(data=your_dataframe, x='numerical_column', bins=30)
# ```
# ### Description:
# Plots the distribution of a numerical variable as a histogram.
# - **Use case:** Understanding the frequency distribution of numerical data.
# - **Key Parameters:**
#   - `x`: Numerical variable.
#   - `bins`: Number of bins to divide the data.
#   - `hue`: Color-code by another variable.
#
# ---
#
# ## 4. sns.scatterplot
# ```python
# sns.scatterplot(data=your_dataframe, x='numerical_column1', y='numerical_column2')
# ```
# ### Description:
# Generates a scatter plot to visualize the relationship between two numerical variables.
# - **Use case:** Identifying correlations or trends.
# - **Key Parameters:**
#   - `x` and `y`: Numerical variables.
#   - `hue`: Optional for color grouping.
#   - `size`: Optional to vary point sizes by a variable.
#
# ---
#
# ## 5. sns.regplot
# ```python
# sns.regplot(data=your_dataframe, x='numerical_column1', y='numerical_column2')
# ```
# ### Description:
# Creates a scatter plot with a fitted regression line to visualize trends.
# - **Use case:** Exploring linear relationships.
# - **Key Parameters:**
#   - `x` and `y`: Numerical variables.
#   - `order`: Polynomial order of the regression.
#   - `ci`: Confidence interval for the regression line.
#
# # Pandas Tips and Tricks
#
# ## 1. **Using `df.query()`**
# The `query()` method allows you to filter a DataFrame using a concise, SQL-like syntax.
#
# ```python
# # Example: Filtering rows where column 'A' is greater than 10 and column 'B' equals 'value'
# filtered_df = df.query("A > 10 and B == 'value'")
# ```
#
# ## 2. **Using `df['columnName'].replace()`**
#
# ```python
# # Example: Replacing all occurrences of -1 with NaN in a column
# df['columnName'] = df['columnName'].replace(-1, np.nan)
# ```
# ```python
# # Replace multiple values at once
# df['columnName] = df['columnName'].replace({-1: np.nan, 0: 'missing'})
# ```
# ## 3. **Iterating with `df.index`*
#
# ```python
# # Example: Looping through the index of a DataFrame
# for ind in df.index:
#     print(f"Index: {ind}, Row data: {df.loc[ind]}")
# ```
# ## 4. **Using `enumerate(df.index)`**
# ```python
# # Example: Printing row index and its corresponding row number
# for i, ind in enumerate(df.index):
#     print(f"Row {i}: Index {ind}, Data: {df.loc[ind]}")
# ```

# %% [markdown]
# ## Lab Assignment
# ### 1. Feature Engineering
# Operate the following feature transformation:
# - categorical column for weekday: 1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'
# - For `ArrDelay feature`, use ax(0,x) transform to get rid of negative values
# - log transformation: create a new column using the log(1+x)
# - Create a new feature: average speed (Distnace/Airtime)
#
# ### 2. EDA review
# Replicate the process above, i.e.,
#
# Generating descriptive statistics, such as mean, standard deviation, and percentiles.
# Visualizing data using:
#   - Boxplots for continuous variables.
#   - Bar charts for discrete variables.
# Calculating missing values, expressed as a percentage for each column.
# Bivariate EDA for Departure Delay and Arrival Delay
# Bivariate EDA for Distance and Airtime
#
# for a subset of flights from ORD to SFO (you don't need to redo the feature engineering part)

# %%
df_2019.head()
# Out:
#        Year  Month  DayofMonth  DayOfWeek UniqueCarrier TailNum  FlightNum  \
# 63489  2019     11           3          7            MQ  N612AE       3525
# 45712  2019      5          21          2            WN  N8310C       1143
# 23037  2019     10           6          7            OO  N196SY       3304
# 53159  2019     10          24          4            MQ  N238NN       3551
# 15357  2019     10          14          1            B6  N804JB        567
#
#       Origin Dest  CRSDepTime  ...  Diverted  CRSElapsedTime  \
# 63489    BMI  ORD        1002  ...         0            60.0
# 45712    BWI  ISP        1805  ...         0            65.0
# 23037    SJC  TUS        1730  ...         0           125.0
# 53159    MDT  ORD         640  ...         0           132.0
# 15357    ATL  FLL        1615  ...         0           114.0
#
#        ActualElapsedTime  AirTime  Distance  CarrierDelay  WeatherDelay  \
# 63489               49.0     32.0       116           4.0           0.0
# 45712               62.0     50.0       220           0.0           0.0
# 23037              122.0    101.0       722           0.0           0.0
# 53159              124.0     99.0       594           NaN           NaN
# 15357               96.0     79.0       581           NaN           NaN
#
#        NASDelay SecurityDelay  LateAircraftDelay
# 63489       0.0           0.0               13.0
# 45712       0.0           0.0               15.0
# 23037       0.0           0.0               22.0
# 53159       NaN           NaN                NaN
# 15357       NaN           NaN                NaN
#
# [5 rows x 29 columns]

# %%
# categorical column for weekday
days = {
    1 : 'Monday',
    2 : 'Tuesday',
    3 : 'Wednesday',
    4 : 'Thursday',
    5 : 'Friday',
    6 : 'Saturday',
    7 : 'Sunday'
}

df_2019_days = df_2019
df_2019_days['DayOfWeekName'] = df_2019_days['DayOfWeek'].map(days)

# %%
# nonnegative ArrDelay
df_2019_arr_delay = df_2019_days
df_2019_arr_delay['ArrDelay'] = df_2019_arr_delay['ArrDelay'].map(lambda x: max(x,0))
df_2019_arr_delay['ArrDelay'].describe()
# Out:
# count    19591.000000
# mean        14.666122
# std         50.645487
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          7.000000
# max       1631.000000
# Name: ArrDelay, dtype: float64

# %%
# Log transform ArrDelay
import math
df_2019_log = df_2019_arr_delay
df_2019_log['ArrDelay'] = df_2019_log['ArrDelay'].map(lambda x: math.log(1 + x))
df_2019_log['ArrDelay'].describe()
# Out:
# count    19591.000000
# mean         1.024847
# std          1.590599
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.079442
# max          7.397562
# Name: ArrDelay, dtype: float64

# %%
# Average flight speed (distance/airtime)
df_2019_avg = df_2019_log
df_2019_avg['AvgSpeed'] = df_2019_avg['Distance']/df_2019_avg['AirTime']
df_2019_avg.head()
# Out:
#        Year  Month  DayofMonth  DayOfWeek UniqueCarrier TailNum  FlightNum  \
# 63489  2019     11           3          7            MQ  N612AE       3525
# 45712  2019      5          21          2            WN  N8310C       1143
# 23037  2019     10           6          7            OO  N196SY       3304
# 53159  2019     10          24          4            MQ  N238NN       3551
# 15357  2019     10          14          1            B6  N804JB        567
#
#       Origin Dest  CRSDepTime  ...  ActualElapsedTime  AirTime  Distance  \
# 63489    BMI  ORD        1002  ...               49.0     32.0       116
# 45712    BWI  ISP        1805  ...               62.0     50.0       220
# 23037    SJC  TUS        1730  ...              122.0    101.0       722
# 53159    MDT  ORD         640  ...              124.0     99.0       594
# 15357    ATL  FLL        1615  ...               96.0     79.0       581
#
#        CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 63489           4.0           0.0       0.0            0.0               13.0
# 45712           0.0           0.0       0.0            0.0               15.0
# 23037           0.0           0.0       0.0            0.0               22.0
# 53159           NaN           NaN       NaN            NaN                NaN
# 15357           NaN           NaN       NaN            NaN                NaN
#
#       DayOfWeekName  AvgSpeed
# 63489        Sunday  3.625000
# 45712       Tuesday  4.400000
# 23037        Sunday  7.148515
# 53159      Thursday  6.000000
# 15357        Monday  7.354430
#
# [5 rows x 31 columns]

# %%
# 2. EDA review
df_2019_final = df_2019_avg

# Generating descriptive statistics, such as mean, standard deviation, and percentiles
df_2019_final_info = get_info(df_2019_final)
df_2019_final_info
# Out:
#                      count         mean          std      min          25%  \
# Year               20000.0  2019.000000     0.000000  2019.00  2019.000000
# Month              20000.0     6.605000     3.423224     1.00     4.000000
# DayofMonth         20000.0    15.738550     8.755634     1.00     8.000000
# DayOfWeek          20000.0     3.918800     2.002850     1.00     2.000000
# FlightNum          20000.0  2565.617600  1798.927455     1.00  1039.000000
# CRSDepTime         20000.0  1333.964250   493.976810     5.00   915.000000
# DepTime            19664.0  1337.476302   509.307628     1.00   915.000000
# DepDelay           19664.0    11.424837    51.869243   -42.00    -5.000000
# TaxiOut            19647.0    17.466789     9.884078     3.00    11.000000
# TaxiIn             19629.0     7.791737     6.434550     1.00     4.000000
# CRSArrTime         20000.0  1491.296300   519.685583     1.00  1104.000000
# ArrTime            19629.0  1467.403179   541.456179     1.00  1049.000000
# ArrDelay           19591.0     1.024847     1.590599     0.00     0.000000
# Cancelled          20000.0     0.017800     0.132227     0.00     0.000000
# Diverted           20000.0     0.002650     0.051411     0.00     0.000000
# CRSElapsedTime     19999.0   142.189009    72.181319    25.00    90.000000
# ActualElapsedTime  19591.0   137.108519    72.327614    27.00    84.000000
# AirTime            19591.0   111.866980    70.325048    14.00    60.000000
# Distance           20000.0   802.951650   591.733252    41.00   369.000000
# CarrierDelay        3711.0    21.726489    70.497614     0.00     0.000000
# WeatherDelay        3711.0     4.644301    45.987671     0.00     0.000000
# NASDelay            3711.0    17.748585    39.760375     0.00     0.000000
# SecurityDelay       3711.0     0.092697     2.002432     0.00     0.000000
# LateAircraftDelay   3711.0    27.980059    53.417101     0.00     0.000000
# AvgSpeed           19591.0     6.745339     1.201454     1.46     6.015757
#
#                            50%          75%          max  missing_percent  \
# Year               2019.000000  2019.000000  2019.000000          0.00000
# Month                 7.000000    10.000000    12.000000          0.00000
# DayofMonth           16.000000    23.000000    31.000000          0.00000
# DayOfWeek             4.000000     6.000000     7.000000          0.00000
# FlightNum          2169.000000  3923.250000  7435.000000          0.00000
# CRSDepTime         1325.000000  1740.000000  2359.000000          0.00000
# DepTime            1330.000000  1750.000000  2400.000000          0.01680
# DepDelay             -2.000000     7.000000  1628.000000          0.01680
# TaxiOut              15.000000    20.000000   143.000000          0.01765
# TaxiIn                6.000000     9.000000   174.000000          0.01855
# CRSArrTime         1520.000000  1925.000000  2359.000000          0.00000
# ArrTime            1504.000000  1922.000000  2400.000000          0.01855
# ArrDelay              0.000000     2.079442     7.397562          0.02045
# Cancelled             0.000000     0.000000     1.000000          0.00000
# Diverted              0.000000     0.000000     1.000000          0.00000
# CRSElapsedTime      125.000000   172.000000   616.000000          0.00005
# ActualElapsedTime   120.000000   167.000000   615.000000          0.02045
# AirTime              94.000000   140.000000   578.000000          0.02045
# Distance            644.000000  1033.250000  5095.000000          0.00000
# CarrierDelay          0.000000    17.000000  1628.000000          0.81445
# WeatherDelay          0.000000     0.000000  1410.000000          0.81445
# NASDelay              3.000000    21.000000   926.000000          0.81445
# SecurityDelay         0.000000     0.000000    75.000000          0.81445
# LateAircraftDelay     2.000000    33.000000   795.000000          0.81445
# AvgSpeed              6.854839     7.559017    10.450739          0.02045
#
#                    unique_val     var_type
# Year                        1  Categorical
# Month                      12  Categorical
# DayofMonth                 31  Categorical
# DayOfWeek                   7  Categorical
# FlightNum                5678   Continuous
# CRSDepTime               1150   Continuous
# DepTime                  1244   Continuous
# DepDelay                  375   Continuous
# TaxiOut                   106   Continuous
# TaxiIn                     78  Categorical
# CRSArrTime               1244   Continuous
# ArrTime                  1323   Continuous
# ArrDelay                  348   Continuous
# Cancelled                   2  Categorical
# Diverted                    2  Categorical
# CRSElapsedTime            407   Continuous
# ActualElapsedTime         418   Continuous
# AirTime                   393   Continuous
# Distance                 1383   Continuous
# CarrierDelay              220   Continuous
# WeatherDelay              104   Continuous
# NASDelay                  180   Continuous
# SecurityDelay              12  Categorical
# LateAircraftDelay         246   Continuous
# AvgSpeed                10734   Continuous

# %%
# Visualizing data using boxplots for continuous variables and bar charts for discrete variables
plt.rcParams.update(**{'figure.dpi':150})
plt.style.use('ggplot') # can skip this - plots are more visually appealing with this style

# Calculate number of rows needed for subplots
num_vars = len(df_2019_final_info.index)
num_rows = (num_vars + 3) // 4  # Round up division

fig,axs = plt.subplots(num_rows,4,figsize=(14,5*num_rows))

for i,ind in enumerate(df_2019_final_info.index):
    # if the value type is continuous, we will use boxplot
    if df_2019_final_info.loc[ind, 'var_type'] == 'Continuous':
        sns.boxplot(df_2019_final,y=ind,ax=axs[i//4, i%4],width=0.5)
        
    # if the value type is discrete, we will use bar chart
    else:
        sns.countplot(data=df_2019_final,x=ind,color='#1f77b4',ax=axs[i//4, i%4])
    
    axs[i//4, i%4].set_title(ind)

fig.tight_layout()

# %%
# Calculating missing values, expressed as a percentage for each column
df_2019_final_per_missing = (df_2019_final.isnull().sum()/df_2019_final.shape[0]).round(2)
df_2019_final_per_missing[df_2019_final_per_missing > 0]
# Out:
# DepTime              0.02
# DepDelay             0.02
# TaxiOut              0.02
# TaxiIn               0.02
# ArrTime              0.02
# ArrDelay             0.02
# CancellationCode     0.98
# ActualElapsedTime    0.02
# AirTime              0.02
# CarrierDelay         0.81
# WeatherDelay         0.81
# NASDelay             0.81
# SecurityDelay        0.81
# LateAircraftDelay    0.81
# AvgSpeed             0.02
# dtype: float64

# %%
# Bivariate EDA for Departure Delay and Arrival Delay
fig,axs = plt.subplots(1,3,figsize=(16,8))

### Histogram and Scatterplot of Departure Delay and Arrival Delay ###
_ = sns.histplot(df_2019_final,x='DepDelay',ax=axs[0],bins=25)
_ = axs[0].set_title('2019: Departure Delay, minutes')

_ = sns.histplot(df_2019_final,x='ArrDelay',ax=axs[1],bins = 25)
_ = axs[1].set_title('2019: Arrival Delay (log transformed), minutes')

_ = sns.scatterplot(df_2019_final,x='DepDelay',y='ArrDelay',ax=axs[2])
_ = axs[2].axline((0, 0), slope=1,color='black',linestyle='dashed')
_ = axs[2].set_title('2019: Departure Delay vs Arrival Delay')

fig.tight_layout()

# %%
# Bivariate EDA for Distance and AirTime
fig,axs = plt.subplots(1,1,figsize=(8,4))

_ = sns.scatterplot(df_2019_final,x='Distance',y='AirTime')
_ = axs.set_title('2019: Distance vs AirTime',fontsize=12)

# %%
# Bivariate EDA for Distance and AirTime for a subset of flights from ORD to SFO
df_ord_sfo = df_2019_final.query("Origin == 'ORD' and Dest == 'SFO'")
print(f'Number of observations for ORD to SFO: {df_ord_sfo.shape[0]}')
df_ord_sfo.head()
# Out:
# Number of observations for ORD to SFO: 19
#        Year  Month  DayofMonth  DayOfWeek UniqueCarrier TailNum  FlightNum  \
# 74713  2019      8           4          7            UA  N78005       1742
# 6845   2019      4          14          7            UA  N69833       1847
# 18401  2019     12          12          4            AA  N337PJ       2639
# 11898  2019      6          15          6            AS  N284VA       1201
# 66296  2019     11          30          6            AS  N320AS        221
#
#       Origin Dest  CRSDepTime  ...  ActualElapsedTime  AirTime  Distance  \
# 74713    ORD  SFO        1935  ...              281.0    242.0      1846
# 6845     ORD  SFO        1546  ...              270.0    248.0      1846
# 18401    ORD  SFO        1514  ...              287.0    273.0      1846
# 11898    ORD  SFO         635  ...              271.0    255.0      1846
# 66296    ORD  SFO         730  ...              290.0    263.0      1846
#
#        CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 74713           NaN           NaN       NaN            NaN                NaN
# 6845            0.0          10.0       0.0            0.0               94.0
# 18401           0.0           0.0      11.0            0.0               99.0
# 11898           NaN           NaN       NaN            NaN                NaN
# 66296           NaN           NaN       NaN            NaN                NaN
#
#       DayOfWeekName  AvgSpeed
# 74713        Sunday  7.628099
# 6845         Sunday  7.443548
# 18401      Thursday  6.761905
# 11898      Saturday  7.239216
# 66296      Saturday  7.019011
#
# [5 rows x 31 columns]

# %%
# Bivariate EDA for Distance and AirTime for ORD to SFO subset
fig,axs = plt.subplots(1,1,figsize=(8,4))

_ = sns.scatterplot(df_ord_sfo, x='Distance', y='AirTime')
_ = axs.set_title('2019: ORD to SFO - Distance vs AirTime', fontsize=12)
