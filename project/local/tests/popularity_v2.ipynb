# %% [markdown]
# # ListenBrainz Popularity Prediction (V2 Tables)
#
# Predict which artists and tracks will reach **≥95th growth percentile** over upcoming 7-day and 30-day windows.
#
# **Models**: XGBoost (classification + regression) and LSTM (PyTorch)
# **Data**: RDS Postgres → PySpark feature engineering → pandas → model training
# **Scope**: Separate artist and track models
#
# | Phase | Description |
# |-------|-------------|
# | 1 | Data loading & feature engineering (Spark JDBC) |
# | 2 | XGBoost classifier + regressor |
# | 3 | LSTM sequence model (PyTorch) |
# | 4 | Evaluation & comparison |

# %% [markdown]
# **Before running, make sure:**
#
# - SSH tunnel is active (localhost:5433 → RDS)
# - .env has fresh AWS credentials
# - Required packages are installed: xgboost, shap, torch, scikit-learn, matplotlib

# %%
import importlib
import sys
import os
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# Add parent dir so we can import project modules
sys.path.insert(0, str(Path.cwd().parent))

import utils
importlib.reload(utils)
from utils import load_db_credentials

print("Imports OK")
# Out:
# Imports OK

# %%
from dotenv import load_dotenv
import json

import psycopg2
import boto3

env_path = Path.cwd().parent.parent / ".env"
print(f"Loading env from: {env_path}  (exists={env_path.exists()})")
load_dotenv(dotenv_path=env_path, override=True)

# Reset boto3 session so it picks up fresh env vars
boto3.DEFAULT_SESSION = None

creds = load_db_credentials()


def _probe_db(c):
    conn = None
    try:
        conn = psycopg2.connect(
            host=c["host"],
            port=int(c["port"]),
            dbname=c["dbname"],
            user=c["user"],
            password=c["password"],
            connect_timeout=6,
            sslmode="prefer",
        )
        with conn.cursor() as cur:
            cur.execute("SELECT current_user, current_database();")
            current_user, current_db = cur.fetchone()
        return True, f"connected as {current_user} to {current_db}"
    except Exception as e:
        return False, str(e)
    finally:
        if conn is not None:
            conn.close()


def _candidate_creds(base):
    candidates = [dict(base)]
    is_loopback = str(base["host"]).strip('"') in {"127.0.0.1", "localhost"}

    # Common local setup uses an SSH tunnel on 5433.
    if is_loopback and int(base["port"]) == 5432:
        alt = dict(base)
        alt["port"] = 5433
        candidates.append(alt)

    # If secret includes username, try it as a fallback.
    secret_username = None
    try:
        sm = boto3.client("secretsmanager", region_name=utils._AWS_REGION)
        secret_str = sm.get_secret_value(SecretId=utils._SECRET_ARN)["SecretString"]
        secret_obj = json.loads(secret_str)
        secret_username = secret_obj.get("username") or secret_obj.get("user")
    except Exception:
        pass

    if secret_username and secret_username != base["user"]:
        alt_user = dict(base)
        alt_user["user"] = secret_username
        candidates.append(alt_user)

        if is_loopback and int(base["port"]) == 5432:
            alt_user_port = dict(alt_user)
            alt_user_port["port"] = 5433
            candidates.append(alt_user_port)

    deduped = []
    seen = set()
    for c in candidates:
        key = (str(c["host"]), int(c["port"]), str(c["dbname"]), str(c["user"]))
        if key not in seen:
            seen.add(key)
            deduped.append(c)
    return deduped


selected = None
errors = []
for cand in _candidate_creds(creds):
    ok, msg = _probe_db(cand)
    if ok:
        selected = cand
        print(
            f"DB probe OK: {cand['host']}:{cand['port']}/{cand['dbname']} "
            f"as {cand['user']} ({msg})"
        )
        break
    errors.append(
        f"{cand['host']}:{cand['port']}/{cand['dbname']} as {cand['user']} -> {msg}"
    )

if selected is None:
    print("Database probe failed for all candidate credentials:")
    for err in errors:
        print(f"  - {err}")

    hints = []
    if any("127.0.0.1:5433" in err and "Connection refused" in err for err in errors):
        hints.append("Start your SSH tunnel to RDS on local port 5433.")
    if any('role "postgres" does not exist' in err for err in errors):
        hints.append("Set PGUSER in project/.env to a valid role for this DB.")

    # Ensure stale Spark state from prior runs cannot leak into later cells.
    try:
        old_spark = globals().get("spark", None)
        if old_spark is not None:
            old_spark.stop()
    except Exception:
        pass
    spark = None

    creds = None
    raise RuntimeError(
        "Could not authenticate to Postgres. " + " ".join(hints)
    )

creds = selected
print(f"Using DB: {creds['host']}:{creds['port']}/{creds['dbname']} as {creds['user']}")
# Out:
# Loading env from: /Users/didiermunezero/Documents/NU/Junior/DE 300/de300-2026wi-stall/project/.env  (exists=True)
# DB probe OK: 127.0.0.1:5433/postgres as postgres (connected as postgres to postgres)
# Using DB: 127.0.0.1:5433/postgres as postgres

# %%
# DATABASE CONNECTION DIAGNOSTIC
print("\n" + "="*70)
print("📊 DATABASE CONNECTION INFO")
print("="*70)
print(f"Host:     {creds['host']}")
print(f"Port:     {creds['port']}")
print(f"Database: {creds['dbname']}")
print(f"User:     {creds['user']}")
print()
if creds['host'] in ['127.0.0.1', 'localhost']:
    print("🏠 CONNECTION TYPE: LOCAL")
    if int(creds['port']) == 5433:
        print("   (SSH tunnel to RDS on port 5433)")
    else:
        print("   (Direct local PostgreSQL on port 5432)")
else:
    print("☁️  CONNECTION TYPE: RDS (Remote)")
    print(f"   (Direct connection to {creds['host']})")
print("="*70 + "\n")
# Out:
# ======================================================================
# 📊 DATABASE CONNECTION INFO
# ======================================================================
# Host:     127.0.0.1
# Port:     5433
# Database: postgres
# User:     postgres
#
# 🏠 CONNECTION TYPE: LOCAL
#    (SSH tunnel to RDS on port 5433)
# ======================================================================

# %%
# # DANGER ZONE: wipe all v2 table data.
# # Set this to True only when you intentionally want to delete everything in v2 tables.
# CONFIRM_DELETE = False

# if not CONFIRM_DELETE:
#     raise RuntimeError(
#         "Safety check blocked. Set CONFIRM_DELETE = True in this cell, then rerun to delete all v2 data."
#     )

# import psycopg2

# tables_to_truncate = [
#     "artist_daily_stats",
#     "track_daily_stats",
#     "artist_daily_listens",
#     "track_daily_listens",
#     "artist_info",
#     "track_info",
# ]

# conn = None
# try:
#     conn = psycopg2.connect(
#         host=creds["host"],
#         port=int(creds["port"]),
#         dbname=creds["dbname"],
#         user=creds["user"],
#         password=creds["password"],
#         sslmode="prefer",
#     )
#     conn.autocommit = False

#     with conn.cursor() as cur:
#         cur.execute("DROP TABLE " + ", ".join(tables_to_truncate) + ";")
#     conn.commit()

#     print("Deleted all rows from v2 tables:")
#     for t in tables_to_truncate:
#         print(f"  - {t}")

# except Exception:
#     if conn is not None:
#         conn.rollback()
#     raise
# finally:
#     if conn is not None:
#         conn.close()

# %%
import importlib
import re

import pandas as pd
import artist_identity

importlib.reload(artist_identity)
from artist_identity import split_slash_artist_credit

TABLE_NAME = "artist_info"
LIMIT = 10
ONLY_SYNTHETIC = False

synthetic_clause = "AND is_synthetic_fallback_key = TRUE" if ONLY_SYNTHETIC else ""

query = f"""
SELECT
    artist_id,
    artist_mbid,
    fallback_key,
    artist_name,
    is_synthetic_fallback_key,
    updated_at
FROM {TABLE_NAME}
WHERE artist_name IS NOT NULL
  {synthetic_clause}
  AND (
      artist_name ILIKE '%%;%%'
      OR artist_name LIKE '%%/%%'
      OR artist_name ILIKE '%% x %%'
      OR artist_name ILIKE '%%feat%%'
      OR artist_name ILIKE '%%with%%'
      OR artist_name ILIKE '%%versus%%'
      OR artist_name ILIKE '%%vs.%%'
      OR artist_name LIKE '%%[%%'
      OR artist_name LIKE '%%(%%'
      OR artist_name ILIKE 'fallback_artist::%%'
      OR artist_name ILIKE '%%||%%'
  )
ORDER BY updated_at DESC, artist_name ASC
LIMIT %(lim)s
"""

params = {"lim": LIMIT}

with psycopg2.connect(**creds) as _conn:
    with _conn.cursor() as _cur:
        _cur.execute(query, params)
        rows = _cur.fetchall()
        cols = [d[0] for d in _cur.description]

df = pd.DataFrame(rows, columns=cols)

feat_pattern = re.compile(
    r"(?<![A-Za-z0-9])(?:featured\s+by(?![A-Za-z0-9])|featuring(?![A-Za-z0-9])|(?:feat|ft)\.(?=\S)|(?:feat|ft)\.?(?![A-Za-z0-9]))",
    flags=re.IGNORECASE,
 )
with_pattern = re.compile(r"(?<![A-Za-z0-9])(?:with|vs\.?|versus)(?![A-Za-z0-9])", flags=re.IGNORECASE)
x_pattern = re.compile(r"\s(?:x|×)\s", flags=re.IGNORECASE)
missing_bracket_pattern = re.compile(r"\[[^\]]*$")
missing_paren_pattern = re.compile(r"\([^\)]*$")

def classify_artist_name(artist_name):
    if not isinstance(artist_name, str) or not artist_name.strip():
        return []

    issue_flags = []
    if ";" in artist_name:
        issue_flags.append("semicolon")
    if split_slash_artist_credit(artist_name):
        issue_flags.append("slash")
    if x_pattern.search(artist_name):
        issue_flags.append("x_with_spaces")
    if feat_pattern.search(artist_name):
        issue_flags.append("feat_marker")
    if with_pattern.search(artist_name):
        issue_flags.append("vs_or_with_marker")
    if missing_bracket_pattern.search(artist_name):
        issue_flags.append("missing_closing_bracket")
    if missing_paren_pattern.search(artist_name):
        issue_flags.append("missing_closing_parenthesis")
    if artist_name.lower().startswith("fallback_artist::"):
        issue_flags.append("fallback_prefix_in_artist_name")
    if "||" in artist_name:
        issue_flags.append("fallback_delimiter_in_artist_name")

    return issue_flags

df["issue_flags"] = df["artist_name"].map(classify_artist_name)
df["issue_count"] = df["issue_flags"].map(len)
df = (
    df[df["issue_count"] > 0]
    .sort_values(["issue_count", "updated_at", "artist_name"], ascending=[False, False, True])
    .reset_index(drop=True)
 )

print(
    f"{len(df):,} suspicious artist rows returned | "
    f"table={TABLE_NAME} | only_synthetic={ONLY_SYNTHETIC} | limit={LIMIT}"
)

if not df.empty:
    issue_summary = df.explode("issue_flags")["issue_flags"].value_counts()
    print("\nIssue counts:")
    print(issue_summary.to_string())

df
# Out:
# 6 suspicious artist rows returned | table=artist_info | only_synthetic=False | limit=10
#
# Issue counts:
# issue_flags
# missing_closing_parenthesis    6
#                               artist_id                           artist_mbid  \
# 0                   fallback_artist:::(                   fallback_artist:::(
# 1       fallback_artist::えみい (テーマパークガール                                   NaN
# 2  c611da21-ad29-49c7-83db-567c0ca22b7a  c611da21-ad29-49c7-83db-567c0ca22b7a
# 3         fallback_artist::ひろりの(ナゾのユニット                                   NaN
# 4             fallback_artist::インカス(ペルー                                   NaN
# 5             fallback_artist::시연 (드림캐쳐                                   NaN
#
#      fallback_key          artist_name  is_synthetic_fallback_key  \
# 0              :(                   :(                      False
# 1  えみい (テーマパークガール       えみい (テーマパークガール                       True
# 2             NaN  じーざす(ワンダフル☆オポチュニティ!                      False
# 3    ひろりの(ナゾのユニット         ひろりの(ナゾのユニット                       True
# 4        インカス(ペルー             インカス(ペルー                       True
# 5        시연 (드림캐쳐             시연 (드림캐쳐                       True
#
#                         updated_at                    issue_flags  issue_count
# 0 2026-03-11 21:55:32.936836+00:00  [missing_closing_parenthesis]            1
# 1 2026-03-11 21:55:32.936836+00:00  [missing_closing_parenthesis]            1
# 2 2026-03-11 21:55:32.936836+00:00  [missing_closing_parenthesis]            1
# 3 2026-03-11 21:55:32.936836+00:00  [missing_closing_parenthesis]            1
# 4 2026-03-11 21:55:32.936836+00:00  [missing_closing_parenthesis]            1
# 5 2026-03-11 21:55:32.936836+00:00  [missing_closing_parenthesis]            1

# %% [markdown]
# ## Phase 1 — Data Loading & Feature Engineering
#
# Load `artist_daily_stats` / `track_daily_stats` joined with raw listen counts via Spark JDBC, engineer momentum/velocity/lag features, build forward-looking target labels, and convert to pandas with a temporal train/test split.

# %%
import os
from pathlib import Path

# Workaround for Spark on Windows: set HADOOP_HOME to avoid winutils.exe requirement
# Create a dummy hadoop/bin directory if it doesn't exist
hadoop_home = Path.home() / ".hadoop"
hadoop_bin = hadoop_home / "bin"
hadoop_bin.mkdir(parents=True, exist_ok=True)

# Point HADOOP_HOME to this directory
os.environ["HADOOP_HOME"] = str(hadoop_home)
os.environ["hadoop.home.dir"] = str(hadoop_home)

print(f"Set HADOOP_HOME to: {hadoop_home}")

from pyspark.sql import SparkSession, functions as F
from pyspark.sql.window import Window
from pyspark import SparkContext

if not globals().get("creds"):
    raise RuntimeError("Run Cell 4 successfully first so valid DB credentials are loaded into `creds`.")


def _reset_spark_state():
    """Clear stale Spark/Py4J state so getOrCreate can start a fresh JVM."""
    try:
        old_spark = globals().get("spark", None)
        if old_spark is not None:
            old_spark.stop()
    except Exception:
        pass

    # Drop static Spark session/context pointers.
    SparkSession._instantiatedSession = None
    SparkSession._activeSession = None
    SparkContext._active_spark_context = None

    # Drop dead Py4J gateway/jvm handles so Spark can relaunch them.
    gateway = getattr(SparkContext, "_gateway", None)
    if gateway is not None:
        try:
            gateway.close()
        except Exception:
            pass
    SparkContext._gateway = None
    SparkContext._jvm = None

    # If these are set, PySpark will try to reconnect to a fixed (possibly dead) gateway port.
    os.environ.pop("PYSPARK_GATEWAY_PORT", None)
    os.environ.pop("PYSPARK_GATEWAY_SECRET", None)


def _build_spark_session():
    return (
        SparkSession.builder
        .master("local[*]")
        .appName("ListenBrainz Popularity")
        .config("spark.jars.packages", "org.postgresql:postgresql:42.7.1")
        .config("spark.driver.memory", "4g")
        .config("spark.sql.session.timeZone", "UTC")
        .getOrCreate()
    )


_reset_spark_state()
spark = _build_spark_session()

jdbc_url = f"jdbc:postgresql://{creds['host']}:{creds['port']}/{creds['dbname']}"
jdbc_props = {
    "user": creds["user"],
    "password": creds["password"],
    "driver": "org.postgresql.Driver",
}

print(
    f"Spark {spark.version} ready — JDBC -> "
    f"{creds['host']}:{creds['port']}/{creds['dbname']} as {creds['user']}"
)
# Out:
# Set HADOOP_HOME to: /Users/didiermunezero/.hadoop
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/Users/didiermunezero/Documents/NU/Junior/DE%20300/.venv/lib/python3.13/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/didiermunezero/.ivy2.5.2/cache
# The jars for the packages stored in: /Users/didiermunezero/.ivy2.5.2/jars
# org.postgresql#postgresql added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-8731bda1-ab49-42de-aeed-3848316a6d60;1.0
# 	confs: [default]
# 	found org.postgresql#postgresql;42.7.1 in central
# 	found org.checkerframework#checker-qual;3.41.0 in central
# :: resolution report :: resolve 132ms :: artifacts dl 7ms
# 	:: modules in use:
# 	org.checkerframework#checker-qual;3.41.0 from central in [default]
# 	org.postgresql#postgresql;42.7.1 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   2   |   0   |   0   |   0   ||   2   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-8731bda1-ab49-42de-aeed-3848316a6d60
# 	confs: [default]
# 	0 artifacts copied, 2 already retrieved (0kB/5ms)
# 26/03/11 20:38:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark 4.1.1 ready — JDBC -> 127.0.0.1:5433/postgres as postgres

# %%
def load_and_engineer(spark, jdbc_url, jdbc_props, stats_table, listens_table, id_col, min_date=None):
    """
    Load stats + daily listens from Postgres, join, and engineer features.
    
    Parameters
    ----------
    min_date : str, optional
        Filter to rows where day >= min_date (e.g., "2026-01-01")
    
    Returns a Spark DataFrame with all original + new columns.
    """
    stats = spark.read.jdbc(url=jdbc_url, table=stats_table, properties=jdbc_props)
    listens = spark.read.jdbc(url=jdbc_url, table=listens_table, properties=jdbc_props)
    
    # DATE FILTER: Only load recent data to avoid sparse historical records
    if min_date:
        print(f"Filtering data to day >= {min_date}")
        stats = stats.filter(F.col("day") >= min_date)
        listens = listens.filter(F.col("day") >= min_date)
    
    print(f"Loaded {stats.count():,} rows from {stats_table}, {listens.count():,} from {listens_table}")

    # Join to get raw listen_count alongside precomputed stats
    df = stats.join(listens, on=["day", id_col], how="inner")

    # Windows for additional features
    w_id = Window.partitionBy(id_col).orderBy("day")
    w_id_7 = w_id.rowsBetween(-6, 0)
    w_id_30 = w_id.rowsBetween(-29, 0)
    w_first = Window.partitionBy(id_col)

    df = (
        df
        # Momentum: short-term acceleration
        .withColumn("_7d_lag7", F.lag("listen_count_past_7_days", 7).over(w_id))
        .withColumn("momentum_7d", F.col("listen_count_past_7_days") - F.col("_7d_lag7"))
        .withColumn("_30d_lag30", F.lag("listen_count_past_30_days", 30).over(w_id))
        .withColumn("momentum_30d", F.col("listen_count_past_30_days") - F.col("_30d_lag30"))
        # Velocity ratio: short-term vs long-term activity
        .withColumn(
            "velocity_ratio",
            F.when(
                F.col("listen_count_past_30_days") > 0,
                F.col("listen_count_past_7_days") / F.col("listen_count_past_30_days"),
            ).otherwise(None),
        )
        # Lifecycle proxy
        .withColumn("_first_day", F.min("day").over(w_first))
        .withColumn("days_since_first_listen", F.datediff(F.col("day"), F.col("_first_day")))
        # Lag features (for LSTM sequences)
        .withColumn("listen_count_lag_1d", F.lag("listen_count", 1).over(w_id))
        .withColumn("listen_count_lag_7d", F.lag("listen_count", 7).over(w_id))
        # Day of week (0=Mon .. 6=Sun); Spark dayofweek is 1=Sun
        .withColumn("day_of_week", (F.dayofweek("day") + 5) % 7)
        .withColumn("is_weekend", F.when(F.dayofweek("day").isin([1, 7]), 1).otherwise(0))
        # Extra features for better signal quality
        .withColumn("listen_count_ma_7d", F.avg("listen_count").over(w_id_7))
        .withColumn("listen_count_ma_30d", F.avg("listen_count").over(w_id_30))
        .withColumn("listen_count_std_7d", F.stddev_pop("listen_count").over(w_id_7))
        .withColumn("log_listen_count", F.log1p(F.col("listen_count")))
        .withColumn(
            "momentum_ratio_7_30",
            F.col("momentum_7d") / (F.abs(F.col("momentum_30d")) + F.lit(1.0)),
        )
        # Drop helper columns
        .drop("_7d_lag7", "_30d_lag30", "_first_day")
    )

    print(f"Feature-engineered DataFrame: {df.count():,} rows, {len(df.columns)} columns")
    return df

print("load_and_engineer() defined")
# Out:
# load_and_engineer() defined

# %%
# CRITICAL FIX: Filter to recent data only (last 2 months from today: 2026-03-09)
# This avoids sparse historical data that creates misleading growth rates
MIN_DATE = "2026-01-01"  # Start of 2026 = ~2 months of data

print(f"Loading data from {MIN_DATE} onward (fixes sparse historical data issue)")

artist_df = load_and_engineer(
    spark, jdbc_url, jdbc_props,
    "artist_daily_stats", "artist_daily_listens", "artist_id",
    min_date=MIN_DATE
)
track_df = load_and_engineer(
    spark, jdbc_url, jdbc_props,
    "track_daily_stats", "track_daily_listens", "recording_id",
    min_date=MIN_DATE
)
# Out:
# Loading data from 2026-01-01 onward (fixes sparse historical data issue)
# Filtering data to day >= 2026-01-01
# Loaded 522,548 rows from artist_daily_stats, 545,032 from artist_daily_listens
# Feature-engineered DataFrame: 545,032 rows, 23 columns
# Filtering data to day >= 2026-01-01
# Loaded 1,647,161 rows from track_daily_stats, 1,664,545 from track_daily_listens
# [Stage 25:=========================>                                (4 + 5) / 9]
# Feature-engineered DataFrame: 1,664,545 rows, 23 columns

# %%
def add_targets(df, id_col, threshold=0.95, min_future_counts=None):
    """
    Add forward-looking target labels:
      - is_popular_7d / is_popular_30d
      - future_growth_pctl_7d / future_growth_pctl_30d

    `min_future_counts` controls how strict each horizon is, e.g.:
      {"7d": 7, "30d": 30} for strict labels,
      {"7d": 3, "30d": 7} for sparse entities.
    """
    if min_future_counts is None:
        min_future_counts = {"7d": 7, "30d": 30}

    min_7 = int(min_future_counts.get("7d", 7))
    min_30 = int(min_future_counts.get("30d", 30))

    w_id = Window.partitionBy(id_col).orderBy("day")
    w_fwd_7 = w_id.rowsBetween(1, 7)
    w_fwd_30 = w_id.rowsBetween(1, 30)

    # Forward-looking aggregates
    df = (
        df
        .withColumn("_max_gp_7", F.max("growth_percentile").over(w_fwd_7))
        .withColumn("_max_gp_30", F.max("growth_percentile").over(w_fwd_30))
        .withColumn("_mean_gp_7", F.avg("growth_percentile").over(w_fwd_7))
        .withColumn("_mean_gp_30", F.avg("growth_percentile").over(w_fwd_30))
        .withColumn("_fwd_count_7", F.count("growth_percentile").over(w_fwd_7))
        .withColumn("_fwd_count_30", F.count("growth_percentile").over(w_fwd_30))
    )

    # Flexible per-horizon filtering
    df = df.filter((F.col("_fwd_count_7") >= min_7) & (F.col("_fwd_count_30") >= min_30))

    df = (
        df
        .withColumn("is_popular_7d", F.when(F.col("_max_gp_7") >= threshold, 1).otherwise(0))
        .withColumn("is_popular_30d", F.when(F.col("_max_gp_30") >= threshold, 1).otherwise(0))
        .withColumn("future_growth_pctl_7d", F.col("_mean_gp_7"))
        .withColumn("future_growth_pctl_30d", F.col("_mean_gp_30"))
        .drop("_max_gp_7", "_max_gp_30", "_mean_gp_7", "_mean_gp_30", "_fwd_count_7", "_fwd_count_30")
    )

    n = df.count()
    if n == 0:
        print(
            f"After target labeling ({id_col}): 0 rows remain "
            f"(requirements: 7d>={min_7}, 30d>={min_30})."
        )
        return df

    pos_7 = df.filter(F.col("is_popular_7d") == 1).count()
    pos_30 = df.filter(F.col("is_popular_30d") == 1).count()
    print(f"After target labeling ({id_col}): {n:,} rows")
    print(f"  Required future rows -> 7d:>={min_7}, 30d:>={min_30}")
    print(f"  is_popular_7d:  {pos_7:,} positive ({100 * pos_7 / n:.2f}%)")
    print(f"  is_popular_30d: {pos_30:,} positive ({100 * pos_30 / n:.2f}%)")
    return df

print("add_targets() defined")
# Out:
# add_targets() defined

# %%
# DATA QUALITY: Add minimum observation requirements per entity
# Filter out entities with too few data points (cause spurious growth rates)
from pyspark.sql import Window as W

def filter_min_observations(df, id_col, min_days=5):
    """Remove entities with fewer than min_days observations."""
    w_id = W.partitionBy(id_col)
    df = df.withColumn("_obs_count", F.count("day").over(w_id))
    initial = df.count()
    df = df.filter(F.col("_obs_count") >= min_days).drop("_obs_count")
    final = df.count()
    removed = initial - final
    print(f"  Filtered entities with <{min_days} days: removed {removed:,} rows ({100*removed/initial:.1f}%)")
    return df

# Artist data is sparse - require at least 3 observations
artist_df = filter_min_observations(artist_df, "artist_id", min_days=3)

# Track data - require at least 5 observations
track_df = filter_min_observations(track_df, "recording_id", min_days=5)

# Now add targets with relaxed requirements (data is already filtered to recent + sufficient obs)
artist_df = add_targets(
    artist_df,
    "artist_id",
    threshold=0.95,
    min_future_counts={"7d": 1, "30d": 1},
)

# Focus on 7-day predictions (performed better in your tests)
track_df = add_targets(
    track_df,
    "recording_id",
    threshold=0.95,
    min_future_counts={"7d": 5, "30d": 7},  # Relaxed 30d since 7d is better
)
# Out:
#   Filtered entities with <3 days: removed 242,740 rows (44.5%)
#   Filtered entities with <5 days: removed 1,536,964 rows (92.3%)
# After target labeling (artist_id): 239,502 rows
#   Required future rows -> 7d:>=1, 30d:>=1
#   is_popular_7d:  11,786 positive (4.92%)
#   is_popular_30d: 11,844 positive (4.95%)
# [Stage 154:==================================================>      (8 + 1) / 9]
# After target labeling (recording_id): 18,378 rows
#   Required future rows -> 7d:>=5, 30d:>=7
#   is_popular_7d:  869 positive (4.73%)
#   is_popular_30d: 1,040 positive (5.66%)

# %%
def _pick_temporal_cutoff(
    pdf,
    target_cols,
    test_days_candidates,
    min_train_rows,
    min_test_rows,
    min_positive_per_target,
):
    """Find the smallest temporal holdout that has enough train rows, test rows, and positives."""
    max_day = pdf["day"].max()
    class_targets = [c for c in target_cols[:2] if c in pdf.columns]

    best_candidate = None
    best_score = (-1, -1, -1, -1, -1)

    for days in test_days_candidates:
        cutoff = max_day - pd.Timedelta(days=int(days))
        train = pdf[pdf["day"] <= cutoff].copy()
        test = pdf[pdf["day"] > cutoff].copy()

        pos_counts = {t: int(test[t].sum()) for t in class_targets}
        min_pos = min(pos_counts.values()) if pos_counts else 0

        meets_train = len(train) >= min_train_rows
        meets_test = len(test) >= min_test_rows
        meets_pos = (min_pos >= min_positive_per_target) if class_targets else True

        candidate = (days, cutoff, train, test, pos_counts, meets_train, meets_test, meets_pos)
        score = (
            int(meets_train),
            int(meets_test),
            int(meets_pos),
            min_pos,
            len(test),
        )

        if score > best_score:
            best_candidate = candidate
            best_score = score

        if meets_train and meets_test and meets_pos:
            return candidate, True

    return best_candidate, False


def spark_to_pandas_split(
    sdf,
    id_col,
    test_days_candidates=(30, 60, 90, 120, 180, 270, 365),
    min_train_rows=50000,
    min_test_rows=5000,
    min_positive_per_target=50,
):
    """
    Convert Spark DF to pandas and do a robust temporal split.
    Chooses a holdout window that tries to satisfy minimum train size, test size, and positives.
    Returns (train_pdf, test_pdf, feature_cols, target_cols).
    """
    target_cols = [
        "is_popular_7d",
        "is_popular_30d",
        "future_growth_pctl_7d",
        "future_growth_pctl_30d",
    ]

    pdf = sdf.toPandas()
    if pdf.empty:
        print(f"Warning: {id_col} dataset is empty after target labeling.")
        empty = pd.DataFrame()
        return empty, empty, [], target_cols

    pdf["day"] = pd.to_datetime(pdf["day"])
    pdf = pdf.sort_values(["day", id_col]).reset_index(drop=True)

    selection, constraints_met = _pick_temporal_cutoff(
        pdf,
        target_cols,
        test_days_candidates,
        min_train_rows,
        min_test_rows,
        min_positive_per_target,
    )

    selected_days, cutoff, train, test, pos_counts, meets_train, meets_test, meets_pos = selection

    if constraints_met:
        print(f"Selected test window for {id_col}: last {selected_days} days (constraints met).")
    else:
        print(f"Selected test window for {id_col}: last {selected_days} days (best fallback).")
        print(
            "  Constraints unmet -> "
            f"min_train_rows={min_train_rows}, min_test_rows={min_test_rows}, "
            f"min_positive_per_target={min_positive_per_target}"
        )
        print(
            f"  Observed -> train_rows={len(train):,}, test_rows={len(test):,}, positives={pos_counts}, "
            f"meets_train={meets_train}, meets_test={meets_test}, meets_pos={meets_pos}"
        )

    # Feature columns: everything except id, day, and targets
    exclude = {id_col, "day"} | set(target_cols)
    feature_cols = [
        c
        for c in pdf.columns
        if c not in exclude and pd.api.types.is_numeric_dtype(pdf[c])
    ]

    if train.empty or test.empty:
        print(
            f"Warning: temporal split for {id_col} produced empty train/test "
            f"(train={len(train)}, test={len(test)})."
        )
    else:
        print(f"Train: {len(train):,} rows ({train['day'].min().date()} - {train['day'].max().date()})")
        print(f"Test:  {len(test):,} rows  ({test['day'].min().date()} - {test['day'].max().date()})")
        print(f"Test positives: {pos_counts}")

    print(f"Features ({len(feature_cols)}): {feature_cols}")
    print(f"Targets: {target_cols}")
    return train, test, feature_cols, target_cols

print("spark_to_pandas_split() defined")
# Out:
# spark_to_pandas_split() defined

# %%
art_train, art_test, art_features, target_cols = spark_to_pandas_split(
    artist_df,
    "artist_id",
    test_days_candidates=(1, 2, 3, 7, 14, 30, 60),
    min_train_rows=200,
    min_test_rows=100,
    min_positive_per_target=5,
)

trk_train, trk_test, trk_features, _ = spark_to_pandas_split(
    track_df,
    "recording_id",
    test_days_candidates=(1, 2, 3, 7, 14, 30, 60),
    min_train_rows=1000,
    min_test_rows=200,
    min_positive_per_target=5,
)

# Keep full post-target datasets in pandas for robust fallback splits.
art_full_pdf = artist_df.toPandas()
trk_full_pdf = track_df.toPandas()

for pdf_name in ["art_full_pdf", "trk_full_pdf"]:
    globals()[pdf_name]["day"] = pd.to_datetime(globals()[pdf_name]["day"])

print(f"Fallback source snapshots: artist={len(art_full_pdf):,}, track={len(trk_full_pdf):,} rows")

# Stop Spark and clear cached session/context references for safe notebook reruns.
from pyspark.sql import SparkSession
from pyspark import SparkContext

try:
    spark.stop()
except Exception:
    pass

SparkSession._instantiatedSession = None
SparkSession._activeSession = None
SparkContext._active_spark_context = None
spark = None
print("Spark session stopped and cleared.")
# Out:
# 26/03/11 20:42:31 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Selected test window for artist_id: last 2 days (constraints met).
# Train: 195,608 rows (2026-01-01 - 2026-02-19)
# Test:  43,894 rows  (2026-02-20 - 2026-02-21)
# Test positives: {'is_popular_7d': 1130, 'is_popular_30d': 1130}
# Features (20): ['growth_percentile', 'cumulative_listen_count', 'listen_count_past_7_days', 'listen_pctl_past_7_days', 'listen_count_past_30_days', 'listen_pctl_past_30_days', 'listen_count', 'momentum_7d', 'momentum_30d', 'velocity_ratio', 'days_since_first_listen', 'listen_count_lag_1d', 'listen_count_lag_7d', 'day_of_week', 'is_weekend', 'listen_count_ma_7d', 'listen_count_ma_30d', 'listen_count_std_7d', 'log_listen_count', 'momentum_ratio_7_30']
# Targets: ['is_popular_7d', 'is_popular_30d', 'future_growth_pctl_7d', 'future_growth_pctl_30d']
# Selected test window for recording_id: last 3 days (constraints met).
# Train: 18,122 rows (2026-01-01 - 2026-02-15)
# Test:  256 rows  (2026-02-16 - 2026-02-18)
# Test positives: {'is_popular_7d': 92, 'is_popular_30d': 92}
# Features (20): ['growth_percentile', 'cumulative_listen_count', 'listen_count_past_7_days', 'listen_pctl_past_7_days', 'listen_count_past_30_days', 'listen_pctl_past_30_days', 'listen_count', 'momentum_7d', 'momentum_30d', 'velocity_ratio', 'days_since_first_listen', 'listen_count_lag_1d', 'listen_count_lag_7d', 'day_of_week', 'is_weekend', 'listen_count_ma_7d', 'listen_count_ma_30d', 'listen_count_std_7d', 'log_listen_count', 'momentum_ratio_7_30']
# Targets: ['is_popular_7d', 'is_popular_30d', 'future_growth_pctl_7d', 'future_growth_pctl_30d']
# Fallback source snapshots: artist=239,502, track=18,378 rows
# Spark session stopped and cleared.

# %%
# Quick sanity check: NaN rates and class balance
for name, df in [("Artist Train", art_train), ("Track Train", trk_train)]:
    print(f"\n{'='*40}")
    print(f"{name}  ({len(df):,} rows)")
    
    if len(df) == 0:
        print("  Skipping analysis: empty dataset")
        continue
    
    feat_cols = art_features if 'Artist' in name else trk_features
    if len(feat_cols) > 0:
        print(f"  NaN %: {(df[feat_cols].isna().mean() * 100).round(1).to_dict()}")
    
    for t in target_cols[:2]:  # classification targets
        if t in df.columns:
            pos = df[t].mean()
            print(f"  {t}: {100*pos:.1f}% positive")
# Out:
# ========================================
# Artist Train  (195,608 rows)
#   NaN %: {'growth_percentile': 0.0, 'cumulative_listen_count': 0.0, 'listen_count_past_7_days': 0.0, 'listen_pctl_past_7_days': 0.0, 'listen_count_past_30_days': 0.0, 'listen_pctl_past_30_days': 0.0, 'listen_count': 0.0, 'momentum_7d': 83.4, 'momentum_30d': 96.7, 'velocity_ratio': 0.0, 'days_since_first_listen': 0.0, 'listen_count_lag_1d': 32.0, 'listen_count_lag_7d': 83.4, 'day_of_week': 0.0, 'is_weekend': 0.0, 'listen_count_ma_7d': 0.0, 'listen_count_ma_30d': 0.0, 'listen_count_std_7d': 0.0, 'log_listen_count': 0.0, 'momentum_ratio_7_30': 96.7}
#   is_popular_7d: 5.4% positive
#   is_popular_30d: 5.5% positive
#
# ========================================
# Track Train  (18,122 rows)
#   NaN %: {'growth_percentile': 0.0, 'cumulative_listen_count': 0.0, 'listen_count_past_7_days': 0.0, 'listen_pctl_past_7_days': 0.0, 'listen_count_past_30_days': 0.0, 'listen_pctl_past_30_days': 0.0, 'listen_count': 0.0, 'momentum_7d': 80.3, 'momentum_30d': 99.9, 'velocity_ratio': 0.0, 'days_since_first_listen': 0.0, 'listen_count_lag_1d': 23.0, 'listen_count_lag_7d': 80.3, 'day_of_week': 0.0, 'is_weekend': 0.0, 'listen_count_ma_7d': 0.0, 'listen_count_ma_30d': 0.0, 'listen_count_std_7d': 0.0, 'log_listen_count': 0.0, 'momentum_ratio_7_30': 99.9}
#   is_popular_7d: 4.3% positive
#   is_popular_30d: 5.2% positive

# %% [markdown]
# ## Phase 2 — XGBoost Models
#
# Train XGBoost classifiers (binary: popular yes/no) and regressors (continuous growth percentile) for both 7-day and 30-day horizons. Temporal expanding-window CV for hyperparameter selection. SHAP for feature importance.

# %%
from xgboost import XGBClassifier, XGBRegressor
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    f1_score,
    precision_score,
    recall_score,
    mean_squared_error,
    mean_absolute_error,
    classification_report,
    roc_curve,
    precision_recall_curve,
)
from sklearn.model_selection import TimeSeriesSplit
import shap

print("XGBoost + sklearn + SHAP imports OK")
# Out:
# XGBoost + sklearn + SHAP imports OK

# %%
def _best_f1_threshold(y_true, scores, threshold_grid=None):
    if threshold_grid is None:
        threshold_grid = np.linspace(0.05, 0.95, 19)

    if len(np.unique(y_true)) < 2:
        return 0.5, float("nan")

    best_th = 0.5
    best_f1 = -1.0
    for th in threshold_grid:
        pred = (scores >= th).astype(int)
        f1 = f1_score(y_true, pred, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_th = float(th)
    return best_th, best_f1


def _nanmean_or_nan(vals):
    vals = np.array(vals, dtype=float)
    if np.all(np.isnan(vals)):
        return float("nan")
    return float(np.nanmean(vals))


def train_xgb_classifier(train_df, test_df, feature_cols, target_col, n_splits=3, param_grid=None):
    """
    Train XGBClassifier with temporal CV + light hyperparameter tuning.
    Uses AP/PR-oriented selection and tunes decision threshold for F1.
    Returns (model, metrics_dict, test_proba).
    """
    if len(feature_cols) == 0:
        print("  No features available for classifier.")
        return None, {}, np.array([])

    X_train = train_df[feature_cols].fillna(0).values
    y_train = train_df[target_col].values.astype(int)
    X_test = test_df[feature_cols].fillna(0).values
    y_test = test_df[target_col].values.astype(int)

    if len(np.unique(y_train)) < 2:
        print("  Training target has a single class; skipping classifier.")
        return None, {}, np.array([])

    pos_rate = float(y_train.mean())
    spw = (1 - pos_rate) / max(pos_rate, 1e-6)

    if param_grid is None:
        param_grid = [
            {"max_depth": 4, "learning_rate": 0.05, "min_child_weight": 1},
            {"max_depth": 6, "learning_rate": 0.05, "min_child_weight": 1},
            {"max_depth": 6, "learning_rate": 0.10, "min_child_weight": 5},
        ]

    tscv = TimeSeriesSplit(n_splits=n_splits)
    best_cfg = None
    best_selection_metric = -np.inf

    for params in param_grid:
        fold_iters = []
        fold_auc = []
        fold_ap = []
        fold_thresholds = []

        for fold, (tr_idx, val_idx) in enumerate(tscv.split(X_train)):
            if len(np.unique(y_train[tr_idx])) < 2:
                continue

            model = XGBClassifier(
                n_estimators=800,
                max_depth=params["max_depth"],
                learning_rate=params["learning_rate"],
                min_child_weight=params["min_child_weight"],
                subsample=0.8,
                colsample_bytree=0.8,
                scale_pos_weight=spw,
                eval_metric="aucpr",
                early_stopping_rounds=40,
                random_state=42,
                tree_method="hist",
            )
            model.fit(
                X_train[tr_idx],
                y_train[tr_idx],
                eval_set=[(X_train[val_idx], y_train[val_idx])],
                verbose=False,
            )

            val_proba = model.predict_proba(X_train[val_idx])[:, 1]
            val_auc = roc_auc_score(y_train[val_idx], val_proba) if len(np.unique(y_train[val_idx])) > 1 else float("nan")
            val_ap = average_precision_score(y_train[val_idx], val_proba) if y_train[val_idx].sum() > 0 else float("nan")
            val_th, _ = _best_f1_threshold(y_train[val_idx], val_proba)

            fold_iters.append(model.best_iteration)
            fold_auc.append(val_auc)
            fold_ap.append(val_ap)
            fold_thresholds.append(val_th)

            print(
                f"  Grid {params} | Fold {fold+1}: "
                f"best_iter={model.best_iteration}, val_AP={val_ap:.4f}, val_AUC={val_auc:.4f}, val_th={val_th:.2f}"
            )

        if len(fold_iters) == 0:
            continue

        mean_ap = _nanmean_or_nan(fold_ap)
        mean_auc = _nanmean_or_nan(fold_auc)
        selection_metric = mean_ap if not np.isnan(mean_ap) else mean_auc

        if np.isnan(selection_metric):
            selection_metric = -np.inf

        if selection_metric > best_selection_metric:
            best_selection_metric = selection_metric
            best_cfg = {
                "params": params,
                "fold_iters": fold_iters,
                "fold_thresholds": fold_thresholds,
                "cv_ap": mean_ap,
                "cv_auc": mean_auc,
            }

    if best_cfg is None:
        print("  No valid classifier config found.")
        return None, {}, np.array([])

    final_n = int(max(50, np.median(best_cfg["fold_iters"])))
    decision_threshold = float(np.nanmedian(best_cfg["fold_thresholds"]))
    chosen = best_cfg["params"]

    model = XGBClassifier(
        n_estimators=final_n,
        max_depth=chosen["max_depth"],
        learning_rate=chosen["learning_rate"],
        min_child_weight=chosen["min_child_weight"],
        subsample=0.8,
        colsample_bytree=0.8,
        scale_pos_weight=spw,
        eval_metric="aucpr",
        random_state=42,
        tree_method="hist",
    )
    model.fit(X_train, y_train, verbose=False)

    test_proba = model.predict_proba(X_test)[:, 1]
    test_pred = (test_proba >= decision_threshold).astype(int)

    test_pos_count = int(y_test.sum())
    test_size = int(len(y_test))
    test_neg_count = int(test_size - test_pos_count)
    train_pos_count = int(y_train.sum())
    has_two_test_classes = len(np.unique(y_test)) > 1

    roc_auc = roc_auc_score(y_test, test_proba) if has_two_test_classes else float("nan")
    pr_auc = average_precision_score(y_test, test_proba) if test_pos_count > 0 else float("nan")

    baseline_prob = np.full(len(y_test), pos_rate, dtype=float)
    baseline_pr_auc = average_precision_score(y_test, baseline_prob) if test_pos_count > 0 else float("nan")
    baseline_pred = (baseline_prob >= decision_threshold).astype(int)
    baseline_f1 = f1_score(y_test, baseline_pred, zero_division=0)

    f1 = f1_score(y_test, test_pred, zero_division=0)
    precision = precision_score(y_test, test_pred, zero_division=0)
    recall = recall_score(y_test, test_pred, zero_division=0)

    metrics = {
        "roc_auc": roc_auc,
        "pr_auc": pr_auc,
        "f1": f1,
        "precision": precision,
        "recall": recall,
        "decision_threshold": decision_threshold,
        "n_estimators": final_n,
        "train_pos_rate": float(pos_rate),
        "train_pos_count": train_pos_count,
        "test_pos_rate": float(y_test.mean()) if len(y_test) > 0 else float("nan"),
        "test_pos_count": test_pos_count,
        "test_neg_count": test_neg_count,
        "test_size": test_size,
        "baseline_pr_auc": baseline_pr_auc,
        "pr_auc_gain": (pr_auc - baseline_pr_auc) if not np.isnan(pr_auc) and not np.isnan(baseline_pr_auc) else float("nan"),
        "baseline_f1": baseline_f1,
        "f1_gain": f1 - baseline_f1,
        "cv_ap": best_cfg["cv_ap"],
        "cv_auc": best_cfg["cv_auc"],
        "selected_max_depth": chosen["max_depth"],
        "selected_learning_rate": chosen["learning_rate"],
        "selected_min_child_weight": chosen["min_child_weight"],
    }

    print(
        f"  Selected params={chosen}, n_estimators={final_n}, threshold={decision_threshold:.2f}"
    )
    print(
        f"  Test: AUC={metrics['roc_auc']:.4f}  AP={metrics['pr_auc']:.4f}  "
        f"F1={metrics['f1']:.4f}  Prec={metrics['precision']:.4f}  Rec={metrics['recall']:.4f}"
    )
    print(
        f"  Baseline: AP={metrics['baseline_pr_auc']:.4f}  AP_gain={metrics['pr_auc_gain']:.4f}  "
        f"F1_gain={metrics['f1_gain']:.4f}"
    )

    return model, metrics, test_proba


def train_xgb_regressor(train_df, test_df, feature_cols, target_col, clf_threshold=0.95, n_splits=3, param_grid=None):
    """
    Train XGBRegressor with temporal CV + light hyperparameter tuning.
    Returns (model, metrics_dict, test_preds).
    """
    if len(feature_cols) == 0:
        print("  No features available for regressor.")
        return None, {}, np.array([])

    X_train = train_df[feature_cols].fillna(0).values
    y_train = train_df[target_col].values
    X_test = test_df[feature_cols].fillna(0).values
    y_test = test_df[target_col].values

    if param_grid is None:
        param_grid = [
            {"max_depth": 4, "learning_rate": 0.05, "min_child_weight": 1},
            {"max_depth": 6, "learning_rate": 0.05, "min_child_weight": 1},
            {"max_depth": 6, "learning_rate": 0.10, "min_child_weight": 5},
        ]

    tscv = TimeSeriesSplit(n_splits=n_splits)
    best_cfg = None
    best_rmse = np.inf

    for params in param_grid:
        fold_iters = []
        fold_rmse = []

        for fold, (tr_idx, val_idx) in enumerate(tscv.split(X_train)):
            model = XGBRegressor(
                n_estimators=800,
                max_depth=params["max_depth"],
                learning_rate=params["learning_rate"],
                min_child_weight=params["min_child_weight"],
                subsample=0.8,
                colsample_bytree=0.8,
                eval_metric="rmse",
                early_stopping_rounds=40,
                random_state=42,
                tree_method="hist",
            )
            model.fit(
                X_train[tr_idx],
                y_train[tr_idx],
                eval_set=[(X_train[val_idx], y_train[val_idx])],
                verbose=False,
            )

            val_pred = model.predict(X_train[val_idx])
            val_rmse = np.sqrt(mean_squared_error(y_train[val_idx], val_pred))

            fold_iters.append(model.best_iteration)
            fold_rmse.append(val_rmse)

            print(f"  Grid {params} | Fold {fold+1}: best_iter={model.best_iteration}, val_RMSE={val_rmse:.4f}")

        if len(fold_iters) == 0:
            continue

        mean_rmse = float(np.mean(fold_rmse))
        if mean_rmse < best_rmse:
            best_rmse = mean_rmse
            best_cfg = {
                "params": params,
                "fold_iters": fold_iters,
                "cv_rmse": mean_rmse,
            }

    if best_cfg is None:
        print("  No valid regressor config found.")
        return None, {}, np.array([])

    chosen = best_cfg["params"]
    final_n = int(max(50, np.median(best_cfg["fold_iters"])))

    model = XGBRegressor(
        n_estimators=final_n,
        max_depth=chosen["max_depth"],
        learning_rate=chosen["learning_rate"],
        min_child_weight=chosen["min_child_weight"],
        subsample=0.8,
        colsample_bytree=0.8,
        eval_metric="rmse",
        random_state=42,
        tree_method="hist",
    )
    model.fit(X_train, y_train, verbose=False)

    test_preds = model.predict(X_test)

    rmse = np.sqrt(mean_squared_error(y_test, test_preds))
    mae = mean_absolute_error(y_test, test_preds)

    baseline_pred = np.full(len(y_test), float(y_train.mean()))
    baseline_rmse = np.sqrt(mean_squared_error(y_test, baseline_pred))
    baseline_mae = mean_absolute_error(y_test, baseline_pred)

    test_binary = (test_preds >= clf_threshold).astype(int)
    y_test_binary = (y_test >= clf_threshold).astype(int)
    baseline_binary = (baseline_pred >= clf_threshold).astype(int)

    has_two_binary_classes = len(np.unique(y_test_binary)) > 1
    test_pos_count = int(y_test_binary.sum())

    roc_auc_thresholded = roc_auc_score(y_test_binary, test_preds) if has_two_binary_classes else float("nan")
    pr_auc_thresholded = average_precision_score(y_test_binary, test_preds) if test_pos_count > 0 else float("nan")
    baseline_pr_auc_thresholded = average_precision_score(y_test_binary, baseline_pred) if test_pos_count > 0 else float("nan")

    f1_thresholded = f1_score(y_test_binary, test_binary, zero_division=0)
    baseline_f1_thresholded = f1_score(y_test_binary, baseline_binary, zero_division=0)

    metrics = {
        "rmse": rmse,
        "mae": mae,
        "baseline_rmse": baseline_rmse,
        "baseline_mae": baseline_mae,
        "rmse_improvement": baseline_rmse - rmse,
        "mae_improvement": baseline_mae - mae,
        "roc_auc_thresholded": roc_auc_thresholded,
        "pr_auc_thresholded": pr_auc_thresholded,
        "baseline_pr_auc_thresholded": baseline_pr_auc_thresholded,
        "pr_auc_gain": (
            pr_auc_thresholded - baseline_pr_auc_thresholded
            if not np.isnan(pr_auc_thresholded) and not np.isnan(baseline_pr_auc_thresholded)
            else float("nan")
        ),
        "f1_thresholded": f1_thresholded,
        "baseline_f1_thresholded": baseline_f1_thresholded,
        "f1_gain": f1_thresholded - baseline_f1_thresholded,
        "n_estimators": final_n,
        "cv_rmse": best_cfg["cv_rmse"],
        "selected_max_depth": chosen["max_depth"],
        "selected_learning_rate": chosen["learning_rate"],
        "selected_min_child_weight": chosen["min_child_weight"],
        "test_pos_count": test_pos_count,
    }

    print(f"  Selected params={chosen}, n_estimators={final_n}")
    print(
        f"  Test: RMSE={metrics['rmse']:.4f}  MAE={metrics['mae']:.4f}  "
        f"th-AUC={metrics['roc_auc_thresholded']:.4f}  th-AP={metrics['pr_auc_thresholded']:.4f}"
    )
    print(
        f"  Baseline: RMSE={metrics['baseline_rmse']:.4f}  RMSE_gain={metrics['rmse_improvement']:.4f}  "
        f"th-AP_gain={metrics['pr_auc_gain']:.4f}"
    )

    return model, metrics, test_preds


print("XGBoost training functions defined")
# Out:
# XGBoost training functions defined

# %%
# FALLBACK: apply only to entities with empty train/test after temporal split
fallback_entities = []
if len(art_train) == 0 or len(art_test) == 0:
    fallback_entities.append(("artist", "art", True))
if len(trk_train) == 0 or len(trk_test) == 0:
    fallback_entities.append(("track", "trk", False))

if fallback_entities:
    print("\n" + "=" * 70)
    print("WARNING: FALLBACK ACTIVATED - temporal split produced empty train/test")
    print("=" * 70 + "\n")

    for entity, df_name, is_artist in fallback_entities:
        # Prefer full post-target snapshot; fallback to existing test split only if snapshot missing.
        source_name = f"{df_name}_full_pdf"
        if source_name in globals() and globals()[source_name] is not None and len(globals()[source_name]) > 0:
            pdf = globals()[source_name].copy()
            source_label = "full"
        else:
            pdf = globals()[f"{df_name}_test"].copy()
            source_label = "test-only"

        if len(pdf) < 2:
            print(f"{entity.title()} - fallback skipped: only {len(pdf)} row(s) available")
            globals()[f"{df_name}_train"] = pdf.iloc[0:0].copy()
            globals()[f"{df_name}_test"] = pdf.copy()
            globals()[f"{df_name}_features"] = []
            print()
            continue

        if not pd.api.types.is_datetime64_any_dtype(pdf["day"]):
            pdf["day"] = pd.to_datetime(pdf["day"])
        pdf = pdf.sort_values("day").reset_index(drop=True)

        # Prefer date-based split, but guarantee non-empty partitions.
        unique_days = np.sort(pdf["day"].dropna().unique())
        if len(unique_days) >= 2:
            day_split_idx = min(max(1, int(len(unique_days) * 0.8)), len(unique_days) - 1)
            test_start_day = unique_days[day_split_idx]
            train = pdf[pdf["day"] < test_start_day].copy()
            test = pdf[pdf["day"] >= test_start_day].copy()
        else:
            train = pdf.iloc[0:0].copy()
            test = pdf.copy()

        # If the date boundary still collapses one side, fallback to row-based split.
        if train.empty or test.empty:
            row_split_idx = min(max(1, int(len(pdf) * 0.8)), len(pdf) - 1)
            train = pdf.iloc[:row_split_idx].copy()
            test = pdf.iloc[row_split_idx:].copy()

        target_cols = [
            "is_popular_7d",
            "is_popular_30d",
            "future_growth_pctl_7d",
            "future_growth_pctl_30d",
        ]
        id_col = "artist_id" if is_artist else "recording_id"
        exclude = {id_col, "day"} | set(target_cols)
        features = [
            c for c in pdf.columns
            if c not in exclude and pd.api.types.is_numeric_dtype(pdf[c])
        ]

        globals()[f"{df_name}_train"] = train
        globals()[f"{df_name}_test"] = test
        globals()[f"{df_name}_features"] = features

        print(f"{entity.title()} - Fallback split (source={source_label}):")
        print(f"  Train: {len(train):,} rows ({train['day'].min().date()} to {train['day'].max().date()})")
        print(f"  Test:  {len(test):,} rows ({test['day'].min().date()} to {test['day'].max().date()})")
        print(f"  Features: {len(features)}")
        print()

    print("=" * 70)
else:
    print("Temporal split produced non-empty train/test for both entities; fallback not needed.")
# Out:
# Temporal split produced non-empty train/test for both entities; fallback not needed.

# %% [markdown]
# ### Train all XGBoost models
# Artist and Track × 7d and 30d horizons × Classifier and Regressor = **8 models**

# %%
xgb_results = {}  # key: (entity, horizon, model_type) -> (model, metrics, preds)

raw_configs = [
    ("artist", art_train, art_test, art_features),
    ("track", trk_train, trk_test, trk_features),
]

# Keep only entities with usable train/test data and features.
configs = []
for entity, train_df, test_df, feat_cols in raw_configs:
    if len(train_df) == 0 or len(test_df) == 0 or len(feat_cols) == 0:
        print(f"Skipping {entity}: empty train/test or no features.")
        continue
    configs.append((entity, train_df, test_df, feat_cols))

xgb_attempted = 0
xgb_successful = 0

for entity, train_df, test_df, feat_cols in configs:
    for horizon in ["7d", "30d"]:
        clf_target = f"is_popular_{horizon}"
        reg_target = f"future_growth_pctl_{horizon}"

        print(f"\n{'='*60}")
        print(f"XGB Classifier - {entity} - {horizon}")
        print(f"{'='*60}")
        xgb_attempted += 1
        m, met, proba = train_xgb_classifier(train_df, test_df, feat_cols, clf_target)
        xgb_results[(entity, horizon, "clf")] = (m, met, proba)
        if m is not None and bool(met):
            xgb_successful += 1

        print(f"\nXGB Regressor - {entity} - {horizon}")
        print(f"{'-'*60}")
        xgb_attempted += 1
        m, met, preds = train_xgb_regressor(train_df, test_df, feat_cols, reg_target)
        xgb_results[(entity, horizon, "reg")] = (m, met, preds)
        if m is not None and bool(met):
            xgb_successful += 1

print(f"\nXGBoost attempts: {xgb_attempted}")
print(f"XGBoost successfully trained: {xgb_successful}")
print(f"XGBoost entries stored: {len(xgb_results)}")
# Out:
# ============================================================
# XGB Classifier - artist - 7d
# ============================================================
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=119, val_AP=0.3804, val_AUC=0.9079, val_th=0.80
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=247, val_AP=0.2512, val_AUC=0.8428, val_th=0.75
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=89, val_AP=0.1866, val_AUC=0.8457, val_th=0.85
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=90, val_AP=0.3813, val_AUC=0.9066, val_th=0.85
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=130, val_AP=0.2517, val_AUC=0.8419, val_th=0.80
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=59, val_AP=0.1967, val_AUC=0.8487, val_th=0.80
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=30, val_AP=0.3781, val_AUC=0.9070, val_th=0.75
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=154, val_AP=0.2530, val_AUC=0.8396, val_th=0.80
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=73, val_AP=0.1949, val_AUC=0.8457, val_th=0.80
#   Selected params={'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1}, n_estimators=90, threshold=0.80
#   Test: AUC=0.8713  AP=0.2317  F1=0.2451  Prec=0.2176  Rec=0.2805
#   Baseline: AP=0.0257  AP_gain=0.2059  F1_gain=0.2451
#
# XGB Regressor - artist - 7d
# ------------------------------------------------------------
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=26, val_RMSE=0.1067
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=774, val_RMSE=0.0909
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=58, val_RMSE=0.1085
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=29, val_RMSE=0.1047
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=590, val_RMSE=0.0896
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=303, val_RMSE=0.1065
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=13, val_RMSE=0.1054
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=346, val_RMSE=0.0897
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=37, val_RMSE=0.1067
#   Selected params={'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1}, n_estimators=303
#   Test: RMSE=0.1260  MAE=0.1018  th-AUC=0.8484  th-AP=0.1039
#   Baseline: RMSE=0.1817  RMSE_gain=0.0557  th-AP_gain=0.0827
#
# ============================================================
# XGB Classifier - artist - 30d
# ============================================================
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=31, val_AP=0.3647, val_AUC=0.9072, val_th=0.75
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=171, val_AP=0.2499, val_AUC=0.8427, val_th=0.75
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=263, val_AP=0.1910, val_AUC=0.8457, val_th=0.80
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=61, val_AP=0.3775, val_AUC=0.9051, val_th=0.85
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=109, val_AP=0.2509, val_AUC=0.8417, val_th=0.75
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=46, val_AP=0.1944, val_AUC=0.8480, val_th=0.80
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=27, val_AP=0.3807, val_AUC=0.9069, val_th=0.75
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=405, val_AP=0.2632, val_AUC=0.8368, val_th=0.80
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=26, val_AP=0.1931, val_AUC=0.8466, val_th=0.80
#   Selected params={'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5}, n_estimators=50, threshold=0.80
#   Test: AUC=0.8718  AP=0.2520  F1=0.2190  Prec=0.6250  Rec=0.1327
#   Baseline: AP=0.0257  AP_gain=0.2263  F1_gain=0.2190
#
# XGB Regressor - artist - 30d
# ------------------------------------------------------------
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=29, val_RMSE=0.0994
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=630, val_RMSE=0.0908
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=77, val_RMSE=0.1085
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=34, val_RMSE=0.0964
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=377, val_RMSE=0.0898
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=68, val_RMSE=0.1066
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=16, val_RMSE=0.0969
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=311, val_RMSE=0.0897
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=128, val_RMSE=0.1065
#   Selected params={'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1}, n_estimators=68
#   Test: RMSE=0.1273  MAE=0.1031  th-AUC=0.8476  th-AP=0.0980
#   Baseline: RMSE=0.1814  RMSE_gain=0.0541  th-AP_gain=0.0768
#
# ============================================================
# XGB Classifier - track - 7d
# ============================================================
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=13, val_AP=0.3452, val_AUC=0.9618, val_th=0.50
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=28, val_AP=0.2192, val_AUC=0.8859, val_th=0.60
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=4, val_AP=0.5486, val_AUC=0.8949, val_th=0.45
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=13, val_AP=0.3452, val_AUC=0.9612, val_th=0.50
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=8, val_AP=0.2156, val_AUC=0.8828, val_th=0.40
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=4, val_AP=0.5454, val_AUC=0.8900, val_th=0.40
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=4, val_AP=0.3261, val_AUC=0.9590, val_th=0.50
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=10, val_AP=0.2254, val_AUC=0.8723, val_th=0.50
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=51, val_AP=0.5559, val_AUC=0.9051, val_th=0.40
#   Selected params={'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1}, n_estimators=50, threshold=0.50
#   Test: AUC=0.9090  AP=0.8820  F1=0.7254  Prec=0.6931  Rec=0.7609
#   Baseline: AP=0.3594  AP_gain=0.5227  F1_gain=0.7254
#
# XGB Regressor - track - 7d
# ------------------------------------------------------------
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=33, val_RMSE=0.0846
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=130, val_RMSE=0.0851
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=59, val_RMSE=0.1241
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=31, val_RMSE=0.0847
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=78, val_RMSE=0.0851
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=192, val_RMSE=0.1188
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=15, val_RMSE=0.0846
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=27, val_RMSE=0.0854
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=141, val_RMSE=0.1171
#   Selected params={'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5}, n_estimators=50
#   Test: RMSE=0.1142  MAE=0.0932  th-AUC=nan  th-AP=nan
#   Baseline: RMSE=0.2309  RMSE_gain=0.1167  th-AP_gain=nan
#
# ============================================================
# XGB Classifier - track - 30d
# ============================================================
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=119, val_AP=0.3466, val_AUC=0.9404, val_th=0.70
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=57, val_AP=0.2719, val_AUC=0.8523, val_th=0.40
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=11, val_AP=0.5760, val_AUC=0.8973, val_th=0.50
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=23, val_AP=0.3391, val_AUC=0.9382, val_th=0.60
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=13, val_AP=0.2351, val_AUC=0.8357, val_th=0.40
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=10, val_AP=0.5780, val_AUC=0.8930, val_th=0.45
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=65, val_AP=0.3388, val_AUC=0.9423, val_th=0.75
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=4, val_AP=0.2456, val_AUC=0.8354, val_th=0.40
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=65, val_AP=0.5822, val_AUC=0.8960, val_th=0.55
#   Selected params={'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1}, n_estimators=57, threshold=0.50
#   Test: AUC=0.9175  AP=0.8936  F1=0.7475  Prec=0.6981  Rec=0.8043
#   Baseline: AP=0.3594  AP_gain=0.5342  F1_gain=0.7475
#
# XGB Regressor - track - 30d
# ------------------------------------------------------------
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=35, val_RMSE=0.0612
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=261, val_RMSE=0.0610
#   Grid {'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=398, val_RMSE=0.0825
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 1: best_iter=35, val_RMSE=0.0608
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 2: best_iter=148, val_RMSE=0.0609
#   Grid {'max_depth': 6, 'learning_rate': 0.05, 'min_child_weight': 1} | Fold 3: best_iter=194, val_RMSE=0.0853
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 1: best_iter=16, val_RMSE=0.0608
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 2: best_iter=57, val_RMSE=0.0606
#   Grid {'max_depth': 6, 'learning_rate': 0.1, 'min_child_weight': 5} | Fold 3: best_iter=130, val_RMSE=0.0836
#   Selected params={'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1}, n_estimators=261
#   Test: RMSE=0.0903  MAE=0.0677  th-AUC=nan  th-AP=nan
#   Baseline: RMSE=0.1976  RMSE_gain=0.1074  th-AP_gain=nan
#
# XGBoost attempts: 8
# XGBoost successfully trained: 8
# XGBoost entries stored: 8

# %%
import pickle
from pathlib import Path

# Create models directory
MODELS_DIR = Path("../models")
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# Save only successfully trained XGBoost models
xgb_save_data = {
    key: value
    for key, value in xgb_results.items()
    if (value[0] is not None) and bool(value[1])
}

xgb_path = MODELS_DIR / "xgb_models.pkl"
with open(xgb_path, "wb") as f:
    pickle.dump(xgb_save_data, f)

print(f"XGBoost result entries available: {len(xgb_results)}")
print(f"XGBoost models saved (trained only): {len(xgb_save_data)}")
print(f"Saved to: {xgb_path}")

# To load models later (skip training):
# with open(xgb_path, "rb") as f:
#     xgb_results = pickle.load(f)
#     print(f"Loaded {len(xgb_results)} trained XGBoost models from {xgb_path}")
# Out:
# XGBoost result entries available: 8
# XGBoost models saved (trained only): 8
# Saved to: ../models/xgb_models.pkl

# %% [markdown]
# ### SHAP Feature Importance (XGBoost Classifiers)

# %%
for entity, train_df, _, feat_cols in configs:
    for horizon in ["7d", "30d"]:
        key = (entity, horizon, "clf")
        if key not in xgb_results:
            continue

        model, met, _ = xgb_results[key]
        if model is None or not met:
            print(f"Skipping SHAP for {entity}-{horizon}: model missing or invalid metrics.")
            continue

        if len(train_df) == 0 or len(feat_cols) == 0:
            print(f"Skipping SHAP for {entity}-{horizon}: empty train/features.")
            continue

        X_sample = train_df[feat_cols].fillna(0).sample(n=min(500, len(train_df)), random_state=42)
        explainer = shap.TreeExplainer(model)
        shap_vals = explainer.shap_values(X_sample)

        print(f"\n{entity.title()} — {horizon} Classifier")
        shap.summary_plot(shap_vals, X_sample, plot_type="bar", max_display=15, show=True)
# Out:
# Artist — 7d Classifier
# Artist — 30d Classifier
# Track — 7d Classifier
# Track — 30d Classifier

# %% [markdown]
# ## Phase 3 — LSTM Sequence Models (PyTorch)
#
# Build sliding-window sequences (T=30 past days → predict label) for each entity. Train LSTM networks for both classification and regression targets.

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"PyTorch device: {device}")
# Out:
# PyTorch device: cpu

# %%
SEQ_LEN = 14  # Shorter context window to make LSTM training feasible on CPU

class TimeSeriesDataset(Dataset):
    """Sliding-window dataset: (SEQ_LEN, n_features) -> target scalar."""

    def __init__(self, df, id_col, feature_cols, target_col, seq_len=SEQ_LEN):
        self.sequences = []
        self.targets = []

        for _, group in df.groupby(id_col):
            group = group.sort_values("day")
            X = group[feature_cols].fillna(0).values.astype(np.float32)
            y = group[target_col].values.astype(np.float32)

            for i in range(seq_len, len(group)):
                self.sequences.append(X[i - seq_len : i])
                self.targets.append(y[i])

        self.sequences = np.array(self.sequences)  # (N, T, F)
        self.targets = np.array(self.targets)      # (N,)

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.sequences[idx], dtype=torch.float32),
            torch.tensor(self.targets[idx], dtype=torch.float32),
        )


class PopularityLSTM(nn.Module):
    def __init__(self, n_features, hidden_size=32, num_layers=1, dropout=0.1, task="clf"):
        super().__init__()
        lstm_dropout = dropout if num_layers > 1 else 0.0
        self.lstm = nn.LSTM(
            n_features,
            hidden_size,
            num_layers,
            batch_first=True,
            dropout=lstm_dropout,
        )
        self.head = nn.Linear(hidden_size, 1)
        self.task = task

    def forward(self, x):
        # x: (batch, seq_len, n_features)
        _, (h_n, _) = self.lstm(x)
        out = self.head(h_n[-1])  # last layer's hidden state
        return out.squeeze(-1)

print(f"TimeSeriesDataset and PopularityLSTM defined (SEQ_LEN={SEQ_LEN})")
# Out:
# TimeSeriesDataset and PopularityLSTM defined (SEQ_LEN=14)

# %%
def train_lstm(
    train_df,
    test_df,
    id_col,
    feature_cols,
    target_col,
    task="clf",
    epochs=8,
    batch_size=1024,
    lr=1e-3,
    seq_len=SEQ_LEN,
    hidden_size=32,
    num_layers=1,
    dropout=0.1,
    max_train_sequences=200_000,
    seed=42,
):
    """
    Train a lightweight LSTM for feasibility on local hardware.
    task='clf' uses BCEWithLogitsLoss, task='reg' uses MSELoss.
    Returns (model, metrics_dict, test_preds).
    """
    if len(feature_cols) == 0:
        print("  Warning: no features; skipping.")
        return None, {}, np.array([])

    train_ds = TimeSeriesDataset(train_df, id_col, feature_cols, target_col, seq_len=seq_len)
    test_ds = TimeSeriesDataset(test_df, id_col, feature_cols, target_col, seq_len=seq_len)
    print(f"  Train sequences: {len(train_ds):,}  Test sequences: {len(test_ds):,}")

    if len(train_ds) == 0 or len(test_ds) == 0:
        print("  Warning: not enough sequences; skipping.")
        return None, {}, np.array([])

    # Cap training sequences to keep wall-clock time manageable.
    if max_train_sequences and len(train_ds) > max_train_sequences:
        rng = np.random.default_rng(seed)
        idx = rng.choice(len(train_ds), size=max_train_sequences, replace=False)
        train_ds.sequences = train_ds.sequences[idx]
        train_ds.targets = train_ds.targets[idx]
        print(f"  Capped train sequences to {len(train_ds):,}")

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    n_features = train_ds.sequences.shape[2]
    model = PopularityLSTM(
        n_features,
        hidden_size=hidden_size,
        num_layers=num_layers,
        dropout=dropout,
        task=task,
    ).to(device)

    if task == "clf":
        pos_rate = float(train_ds.targets.mean())
        if pos_rate <= 0 or pos_rate >= 1:
            print("  Warning: training target has a single class; skipping.")
            return None, {}, np.array([])
        pos_weight = torch.tensor([(1 - pos_rate) / max(pos_rate, 1e-6)], device=device)
        criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    else:
        criterion = nn.MSELoss()

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=2, factor=0.5)

    best_loss = float("inf")
    best_state = None
    patience_counter = 0
    early_stop_patience = 4

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            out = model(X_batch)
            loss = criterion(out, y_batch)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            train_loss += loss.item() * len(y_batch)
        train_loss /= len(train_ds)

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                out = model(X_batch)
                val_loss += criterion(out, y_batch).item() * len(y_batch)
        val_loss /= len(test_ds)
        scheduler.step(val_loss)

        if val_loss < best_loss:
            best_loss = val_loss
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1

        if (epoch + 1) % 2 == 0 or epoch == 0:
            print(f"  Epoch {epoch+1:3d}: train_loss={train_loss:.4f}  val_loss={val_loss:.4f}")

        if patience_counter >= early_stop_patience:
            print(f"  Early stopping at epoch {epoch+1}")
            break

    model.load_state_dict(best_state)
    model.eval()
    all_preds, all_targets = [], []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch = X_batch.to(device)
            out = model(X_batch)
            if task == "clf":
                out = torch.sigmoid(out)
            all_preds.append(out.cpu().numpy())
            all_targets.append(y_batch.numpy())

    preds = np.concatenate(all_preds)
    targets = np.concatenate(all_targets)

    metrics = {}
    if task == "clf":
        decision_threshold, _ = _best_f1_threshold(targets, preds)
        binary_preds = (preds >= decision_threshold).astype(int)

        has_two_classes = len(np.unique(targets)) > 1
        test_pos_count = int(targets.sum())
        test_size = int(len(targets))
        test_neg_count = int(test_size - test_pos_count)
        train_pos_rate = float(train_ds.targets.mean())

        roc_auc = roc_auc_score(targets, preds) if has_two_classes else float("nan")
        pr_auc = average_precision_score(targets, preds) if test_pos_count > 0 else float("nan")

        baseline_prob = np.full(len(targets), train_pos_rate)
        baseline_pr_auc = average_precision_score(targets, baseline_prob) if test_pos_count > 0 else float("nan")
        baseline_binary = (baseline_prob >= decision_threshold).astype(int)
        baseline_f1 = f1_score(targets, baseline_binary, zero_division=0)

        f1 = f1_score(targets, binary_preds, zero_division=0)
        precision = precision_score(targets, binary_preds, zero_division=0)
        recall = recall_score(targets, binary_preds, zero_division=0)

        metrics = {
            "roc_auc": roc_auc,
            "pr_auc": pr_auc,
            "f1": f1,
            "precision": precision,
            "recall": recall,
            "decision_threshold": decision_threshold,
            "train_pos_rate": train_pos_rate,
            "test_pos_rate": float(targets.mean()) if len(targets) > 0 else float("nan"),
            "test_pos_count": test_pos_count,
            "test_neg_count": test_neg_count,
            "test_size": test_size,
            "baseline_pr_auc": baseline_pr_auc,
            "pr_auc_gain": (pr_auc - baseline_pr_auc) if not np.isnan(pr_auc) and not np.isnan(baseline_pr_auc) else float("nan"),
            "baseline_f1": baseline_f1,
            "f1_gain": f1 - baseline_f1,
        }

        print(
            f"  Test: AUC={metrics['roc_auc']:.4f}  AP={metrics['pr_auc']:.4f}  "
            f"F1={metrics['f1']:.4f}  Prec={metrics['precision']:.4f}  Rec={metrics['recall']:.4f}  "
            f"th={metrics['decision_threshold']:.2f}"
        )
        print(
            f"  Baseline: AP={metrics['baseline_pr_auc']:.4f}  AP_gain={metrics['pr_auc_gain']:.4f}  "
            f"F1_gain={metrics['f1_gain']:.4f}"
        )
    else:
        rmse = np.sqrt(mean_squared_error(targets, preds))
        mae = mean_absolute_error(targets, preds)

        baseline_pred = np.full(len(targets), float(train_ds.targets.mean()))
        baseline_rmse = np.sqrt(mean_squared_error(targets, baseline_pred))
        baseline_mae = mean_absolute_error(targets, baseline_pred)

        binary_preds = (preds >= 0.95).astype(int)
        binary_targets = (targets >= 0.95).astype(int)
        baseline_binary = (baseline_pred >= 0.95).astype(int)

        has_two_binary = len(np.unique(binary_targets)) > 1
        test_pos_count = int(binary_targets.sum())

        roc_auc_thresholded = roc_auc_score(binary_targets, preds) if has_two_binary else float("nan")
        pr_auc_thresholded = average_precision_score(binary_targets, preds) if test_pos_count > 0 else float("nan")
        baseline_pr_auc_thresholded = average_precision_score(binary_targets, baseline_pred) if test_pos_count > 0 else float("nan")

        f1_thresholded = f1_score(binary_targets, binary_preds, zero_division=0)
        baseline_f1_thresholded = f1_score(binary_targets, baseline_binary, zero_division=0)

        metrics = {
            "rmse": rmse,
            "mae": mae,
            "baseline_rmse": baseline_rmse,
            "baseline_mae": baseline_mae,
            "rmse_improvement": baseline_rmse - rmse,
            "mae_improvement": baseline_mae - mae,
            "roc_auc_thresholded": roc_auc_thresholded,
            "pr_auc_thresholded": pr_auc_thresholded,
            "baseline_pr_auc_thresholded": baseline_pr_auc_thresholded,
            "pr_auc_gain": (
                pr_auc_thresholded - baseline_pr_auc_thresholded
                if not np.isnan(pr_auc_thresholded) and not np.isnan(baseline_pr_auc_thresholded)
                else float("nan")
            ),
            "f1_thresholded": f1_thresholded,
            "baseline_f1_thresholded": baseline_f1_thresholded,
            "f1_gain": f1_thresholded - baseline_f1_thresholded,
            "test_pos_count": test_pos_count,
        }

        print(
            f"  Test: RMSE={metrics['rmse']:.4f}  MAE={metrics['mae']:.4f}  "
            f"th-AUC={metrics['roc_auc_thresholded']:.4f}  th-AP={metrics['pr_auc_thresholded']:.4f}"
        )
        print(
            f"  Baseline: RMSE={metrics['baseline_rmse']:.4f}  RMSE_gain={metrics['rmse_improvement']:.4f}  "
            f"th-AP_gain={metrics['pr_auc_gain']:.4f}"
        )

    return model, metrics, preds


print("train_lstm() defined")
# Out:
# train_lstm() defined

# %% [markdown]
# ### Train LSTM models (track-only, budgeted)
# To keep runtime practical, we train only track models and use a reduced training budget (shorter sequence length, capped samples, fewer epochs).

# %%
lstm_results = {}  # key: (entity, horizon, model_type) -> (model, metrics, preds)

# Track-only LSTM to keep training feasible in local runtime.
lstm_configs = [
    ("track", trk_train, trk_test, "recording_id", trk_features),
]

lstm_train_params = {
    "epochs": 6,
    "batch_size": 1024,
    "lr": 1e-3,
    "seq_len": 14,
    "hidden_size": 32,
    "num_layers": 1,
    "dropout": 0.1,
    "max_train_sequences": 200_000,
}

lstm_attempted = 0
lstm_successful = 0

for entity, train_df, test_df, id_col, feat_cols in lstm_configs:
    if len(train_df) == 0 or len(test_df) == 0 or len(feat_cols) == 0:
        print(f"Skipping {entity}: empty train/test or no features.")
        continue

    for horizon in ["7d", "30d"]:
        clf_target = f"is_popular_{horizon}"
        reg_target = f"future_growth_pctl_{horizon}"

        print(f"\n{'='*60}")
        print(f"LSTM Classifier - {entity} - {horizon}")
        print(f"{'='*60}")
        lstm_attempted += 1
        m, met, preds = train_lstm(
            train_df,
            test_df,
            id_col,
            feat_cols,
            clf_target,
            task="clf",
            **lstm_train_params,
        )
        if m is not None and bool(met):
            lstm_results[(entity, horizon, "clf")] = (m, met, preds)
            lstm_successful += 1
        else:
            print("  Classifier not stored (training skipped or invalid metrics).")

        print(f"\nLSTM Regressor - {entity} - {horizon}")
        print(f"{'-'*60}")
        lstm_attempted += 1
        m, met, preds = train_lstm(
            train_df,
            test_df,
            id_col,
            feat_cols,
            reg_target,
            task="reg",
            **lstm_train_params,
        )
        if m is not None and bool(met):
            lstm_results[(entity, horizon, "reg")] = (m, met, preds)
            lstm_successful += 1
        else:
            print("  Regressor not stored (training skipped or invalid metrics).")

print(f"\nLSTM attempts: {lstm_attempted}")
print(f"LSTM successfully trained: {lstm_successful}")
print(f"LSTM entries stored: {len(lstm_results)}")
# Out:
# ============================================================
# LSTM Classifier - track - 7d
# ============================================================
#   Train sequences: 560  Test sequences: 0
#   Warning: not enough sequences; skipping.
#   Classifier not stored (training skipped or invalid metrics).
#
# LSTM Regressor - track - 7d
# ------------------------------------------------------------
#   Train sequences: 560  Test sequences: 0
#   Warning: not enough sequences; skipping.
#   Regressor not stored (training skipped or invalid metrics).
#
# ============================================================
# LSTM Classifier - track - 30d
# ============================================================
#   Train sequences: 560  Test sequences: 0
#   Warning: not enough sequences; skipping.
#   Classifier not stored (training skipped or invalid metrics).
#
# LSTM Regressor - track - 30d
# ------------------------------------------------------------
#   Train sequences: 560  Test sequences: 0
#   Warning: not enough sequences; skipping.
#   Regressor not stored (training skipped or invalid metrics).
#
# LSTM attempts: 4
# LSTM successfully trained: 0
# LSTM entries stored: 0

# %%
# Save LSTM models (PyTorch state_dicts + metrics)
lstm_path = MODELS_DIR / "lstm_models.pt"
lstm_save_data = {}

for key, (model, metrics, preds) in lstm_results.items():
    if model is not None and bool(metrics):
        lstm_save_data[key] = {
            "state_dict": model.state_dict(),
            "metrics": metrics,
            # Store architecture params for reconstruction
            "n_features": model.lstm.input_size,
            "hidden_size": model.lstm.hidden_size,
            "num_layers": model.lstm.num_layers,
            "task": model.task,
        }

torch.save(lstm_save_data, lstm_path)
print(f"LSTM entries available: {len(lstm_results)}")
print(f"LSTM models saved (trained only): {len(lstm_save_data)}")
print(f"Saved to: {lstm_path}")

# To load models later (skip training):
# lstm_save_data = torch.load(lstm_path, map_location=device)
# lstm_results = {}
# for key, data in lstm_save_data.items():
#     model = PopularityLSTM(
#         data["n_features"],
#         data["hidden_size"],
#         data["num_layers"],
#         task=data["task"]
#     ).to(device)
#     model.load_state_dict(data["state_dict"])
#     model.eval()
#     lstm_results[key] = (model, data["metrics"], None)  # preds not saved
# print(f"Loaded {len(lstm_results)} LSTM models from {lstm_path}")
# Out:
# LSTM entries available: 0
# LSTM models saved (trained only): 0
# Saved to: ../models/lstm_models.pt

# %% [markdown]
# ## Phase 4 — Evaluation & Comparison
#
# Side-by-side metrics table, ROC curves, precision-recall curves, and top-N predicted rising entities vs actuals.

# %%
# Build comparison metrics table with reliability + baseline checks
rows = []
for key_set, label in [(xgb_results, "XGBoost"), (lstm_results, "LSTM")]:
    for (entity, horizon, mtype), (_, metrics, _) in key_set.items():
        if not metrics:
            continue
        row = {"Model": label, "Entity": entity, "Horizon": horizon, "Type": mtype}
        row.update(metrics)
        rows.append(row)

metrics_df = pd.DataFrame(rows)

if metrics_df.empty:
    print("No metrics available yet. Run training cells first.")
else:
    # Reliability: classifier evaluation is unreliable with too few positives/negatives in test.
    metrics_df["evaluation_reliable"] = True
    clf_mask = metrics_df["Type"] == "clf"

    if {"test_pos_count", "test_neg_count"}.issubset(metrics_df.columns):
        metrics_df.loc[clf_mask, "evaluation_reliable"] = (
            (metrics_df.loc[clf_mask, "test_pos_count"].fillna(0) >= 10)
            & (metrics_df.loc[clf_mask, "test_neg_count"].fillna(0) >= 10)
        )
    elif "test_pos_count" in metrics_df.columns:
        metrics_df.loc[clf_mask, "evaluation_reliable"] = (
            metrics_df.loc[clf_mask, "test_pos_count"].fillna(0) >= 10
        )

    # Baseline pass criteria
    metrics_df["beats_baseline"] = False

    if "pr_auc_gain" in metrics_df.columns:
        metrics_df.loc[clf_mask, "beats_baseline"] = (
            metrics_df.loc[clf_mask, "pr_auc_gain"].fillna(-np.inf) > 0
        )

    reg_mask = metrics_df["Type"] == "reg"
    if "rmse_improvement" in metrics_df.columns:
        metrics_df.loc[reg_mask, "beats_baseline"] = (
            metrics_df.loc[reg_mask, "rmse_improvement"].fillna(-np.inf) > 0
        )

    metrics_df["status"] = np.where(
        metrics_df["evaluation_reliable"] & metrics_df["beats_baseline"],
        "PASS",
        "NEEDS_WORK",
    )

    display_cols = [
        "Model", "Entity", "Horizon", "Type", "status",
        "evaluation_reliable", "beats_baseline",
        "roc_auc", "pr_auc", "f1", "precision", "recall",
        "rmse", "mae",
        "baseline_pr_auc", "pr_auc_gain",
        "baseline_rmse", "rmse_improvement",
        "decision_threshold", "test_pos_count", "test_neg_count", "test_size",
    ]
    display_cols = [c for c in display_cols if c in metrics_df.columns]

    display(
        metrics_df[display_cols]
        .sort_values(["Model", "Entity", "Horizon", "Type"])
        .reset_index(drop=True)
        .round(4)
    )

    print("\nStatus summary:")
    print(metrics_df["status"].value_counts(dropna=False).to_string())

    unreliable = metrics_df[~metrics_df["evaluation_reliable"]]
    if len(unreliable) > 0:
        cols = [c for c in ["Model", "Entity", "Horizon", "Type", "test_pos_count", "test_neg_count", "test_size"] if c in unreliable.columns]
        print("\nUnreliable evaluations (insufficient class coverage in test):")
        print(unreliable[cols].to_string(index=False))
# Out:
#      Model  Entity Horizon Type status  evaluation_reliable  beats_baseline  \
# 0  XGBoost  artist     30d  clf   PASS                 True            True
# 1  XGBoost  artist     30d  reg   PASS                 True            True
# 2  XGBoost  artist      7d  clf   PASS                 True            True
# 3  XGBoost  artist      7d  reg   PASS                 True            True
# 4  XGBoost   track     30d  clf   PASS                 True            True
# 5  XGBoost   track     30d  reg   PASS                 True            True
# 6  XGBoost   track      7d  clf   PASS                 True            True
# 7  XGBoost   track      7d  reg   PASS                 True            True
#
#    roc_auc  pr_auc      f1  ...    rmse     mae  baseline_pr_auc  pr_auc_gain  \
# 0   0.8718  0.2520  0.2190  ...     NaN     NaN           0.0257       0.2263
# 1      NaN     NaN     NaN  ...  0.1273  0.1031              NaN       0.0768
# 2   0.8713  0.2317  0.2451  ...     NaN     NaN           0.0257       0.2059
# 3      NaN     NaN     NaN  ...  0.1260  0.1018              NaN       0.0827
# 4   0.9175  0.8936  0.7475  ...     NaN     NaN           0.3594       0.5342
# 5      NaN     NaN     NaN  ...  0.0903  0.0677              NaN          NaN
# 6   0.9090  0.8820  0.7254  ...     NaN     NaN           0.3594       0.5227
# 7      NaN     NaN     NaN  ...  0.1142  0.0932              NaN          NaN
#
#    baseline_rmse  rmse_improvement  decision_threshold  test_pos_count  \
# 0            NaN               NaN                 0.8            1130
# 1         0.1814            0.0541                 NaN             930
# 2            NaN               NaN                 0.8            1130
# 3         0.1817            0.0557                 NaN             930
# 4            NaN               NaN                 0.5              92
# 5         0.1976            0.1074                 NaN               0
# 6            NaN               NaN                 0.5              92
# 7         0.2309            0.1167                 NaN               0
#
#    test_neg_count  test_size
# 0         42764.0    43894.0
# 1             NaN        NaN
# 2         42764.0    43894.0
# 3             NaN        NaN
# 4           164.0      256.0
# 5             NaN        NaN
# 6           164.0      256.0
# 7             NaN        NaN
#
# [8 rows x 22 columns]
# Status summary:
# status
# PASS    8

# %% [markdown]
# ### ROC & Precision-Recall Curves (Classifiers only)

# %%
fig, axes = plt.subplots(2, 4, figsize=(24, 10))

for col_offset, (entity, _, test_df, feat_cols) in enumerate(configs):
    for row, horizon in enumerate(["7d", "30d"]):
        target_col = f"is_popular_{horizon}"

        # --- ROC ---
        ax_roc = axes[row][col_offset * 2]
        ax_roc.set_title(f"ROC — {entity.title()} {horizon}")
        ax_roc.plot([0, 1], [0, 1], "k--", alpha=0.3)

        # XGBoost
        xgb_proba = xgb_results[(entity, horizon, "clf")][2]
        xgb_y = test_df[target_col].values

        # Check if both classes present (need for ROC/AUC)
        n_classes = len(np.unique(xgb_y))
        if n_classes > 1:
            fpr, tpr, _ = roc_curve(xgb_y, xgb_proba)
            ax_roc.plot(fpr, tpr, label=f"XGB (AUC={roc_auc_score(xgb_y, xgb_proba):.3f})")
        else:
            ax_roc.text(
                0.5,
                0.5,
                f"Only one class in test set\n({int(xgb_y[0])})",
                ha="center",
                va="center",
                transform=ax_roc.transAxes,
            )

        # LSTM (optional; may be track-only)
        lstm_y = np.array([])
        lstm_key = (entity, horizon, "clf")
        if lstm_key in lstm_results and len(lstm_results[lstm_key][2]) > 0:
            lstm_preds = lstm_results[lstm_key][2]
            id_col = "artist_id" if entity == "artist" else "recording_id"
            lstm_ds = TimeSeriesDataset(test_df, id_col, feat_cols, target_col, seq_len=SEQ_LEN)
            lstm_y = lstm_ds.targets

            if len(np.unique(lstm_y)) > 1 and len(lstm_preds) == len(lstm_y):
                fpr2, tpr2, _ = roc_curve(lstm_y, lstm_preds)
                ax_roc.plot(fpr2, tpr2, label=f"LSTM (AUC={roc_auc_score(lstm_y, lstm_preds):.3f})")

        ax_roc.legend(fontsize=9)
        ax_roc.set_xlabel("FPR")
        ax_roc.set_ylabel("TPR")

        # --- Precision-Recall ---
        ax_pr = axes[row][col_offset * 2 + 1]
        ax_pr.set_title(f"PR — {entity.title()} {horizon}")

        if n_classes > 1:
            prec, rec, _ = precision_recall_curve(xgb_y, xgb_proba)
            ax_pr.plot(rec, prec, label="XGB")
        else:
            ax_pr.text(
                0.5,
                0.5,
                f"Only one class in test set\n({int(xgb_y[0])})",
                ha="center",
                va="center",
                transform=ax_pr.transAxes,
            )

        if len(lstm_y) > 0 and lstm_key in lstm_results and len(np.unique(lstm_y)) > 1:
            lstm_preds = lstm_results[lstm_key][2]
            if len(lstm_preds) == len(lstm_y):
                prec2, rec2, _ = precision_recall_curve(lstm_y, lstm_preds)
                ax_pr.plot(rec2, prec2, label="LSTM")

        ax_pr.legend(fontsize=9)
        ax_pr.set_xlabel("Recall")
        ax_pr.set_ylabel("Precision")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top-N Predicted Rising Entities vs Actual
# Show the top 20 entities predicted most likely to be "popular" and whether they actually were.

# %%
TOP_N = 20

for entity, _, test_df, feat_cols in configs:
    id_col = "artist_id" if entity == "artist" else "recording_id"
    for horizon in ["7d", "30d"]:
        target_col = f"is_popular_{horizon}"
        proba = xgb_results[(entity, horizon, "clf")][2]

        result = test_df[[id_col, "day", target_col]].copy()
        result["xgb_score"] = proba

        # Aggregate: mean predicted score per entity
        entity_scores = (
            result.groupby(id_col)
            .agg(
                mean_xgb_score=("xgb_score", "mean"),
                actually_popular=(target_col, "max"),
                n_days=("day", "count"),
            )
            .sort_values("mean_xgb_score", ascending=False)
            .head(TOP_N)
        )

        hit_rate = entity_scores["actually_popular"].mean()
        prevalence = result[target_col].mean()
        lift = (hit_rate / prevalence) if prevalence > 0 else float("nan")

        print(f"\n{entity.title()} - {horizon}: Top {TOP_N} predicted")
        print(f"  Hit rate: {100*hit_rate:.1f}%")
        print(f"  Test-set prevalence: {100*prevalence:.1f}%")
        print(f"  Lift vs random baseline: {lift:.2f}x")

        display(entity_scores.round(4))
# Out:
# Artist - 7d: Top 20 predicted
#   Hit rate: 100.0%
#   Test-set prevalence: 2.6%
#   Lift vs random baseline: 38.84x
#                                       mean_xgb_score  actually_popular  n_days
# artist_id
# 4b96aeb8-db1a-45b0-b665-ab24858408af          0.9209                 1       2
# 1acaadc8-53e7-4e28-bca0-a7a0915bb15a          0.9209                 1       2
# fallback_artist::jambinai                     0.9201                 1       1
# fallback_artist::quartz                       0.9165                 1       1
# 26f62bfe-2bf3-4181-bb71-7cacd8222465          0.9151                 1       1
# fallback_artist::i create                     0.9151                 1       1
# 980f4f24-5d8f-4f80-8cbb-0a9d776312b2          0.9151                 1       1
# 989e5860-2837-4add-9814-668cb25f6f1e          0.9151                 1       1
# fallback_artist::abie rotenberg               0.9151                 1       1
# fallback_artist::agraceful                    0.9144                 1       1
# ca4231dc-68aa-4b5c-b16d-22aa418c281d          0.9144                 1       1
# fallback_artist::secret clubhouse             0.9144                 1       1
# fallback_artist::seth stewart                 0.9143                 1       1
# fallback_artist::キング                          0.9114                 1       1
# fallback_artist::roonin                       0.9091                 1       1
# fallback_artist::yung aeon                    0.9082                 1       2
# ea22387f-1b16-4de8-8026-f7464febc11a          0.9082                 1       2
# a64f84d6-569a-49d6-a11b-961fa52cfced          0.9082                 1       2
# fallback_artist::мультfильмы                  0.9082                 1       2
# fallback_artist::los thuthanaka               0.9082                 1       2
# Artist - 30d: Top 20 predicted
#   Hit rate: 100.0%
#   Test-set prevalence: 2.6%
#   Lift vs random baseline: 38.84x
#                                         mean_xgb_score  actually_popular  \
# artist_id
# fallback_artist::jambinai                       0.9344                 1
# fallback_artist::キング                            0.9255                 1
# fallback_artist::rolobi                         0.9216                 1
# fallback_artist::quartz                         0.9213                 1
# fallback_artist::サロン                            0.9142                 1
# 980f4f24-5d8f-4f80-8cbb-0a9d776312b2            0.9113                 1
# fallback_artist::abie rotenberg                 0.9113                 1
# 26f62bfe-2bf3-4181-bb71-7cacd8222465            0.9113                 1
# 989e5860-2837-4add-9814-668cb25f6f1e            0.9113                 1
# fallback_artist::i create                       0.9113                 1
# fallback_artist::seth stewart                   0.9088                 1
# 1acaadc8-53e7-4e28-bca0-a7a0915bb15a            0.9002                 1
# 4b96aeb8-db1a-45b0-b665-ab24858408af            0.9002                 1
# fallback_artist::don vilanova botafogo          0.8921                 1
# fallback_artist::roonin                         0.8919                 1
# fallback_artist::secret clubhouse               0.8912                 1
# ca4231dc-68aa-4b5c-b16d-22aa418c281d            0.8912                 1
# fallback_artist::agraceful                      0.8912                 1
# fallback_artist::joel shearer                   0.8902                 1
# fallback_artist::yung aeon                      0.8813                 1
#
#                                         n_days
# artist_id
# fallback_artist::jambinai                    1
# fallback_artist::キング                         1
# fallback_artist::rolobi                      1
# fallback_artist::quartz                      1
# fallback_artist::サロン                         1
# 980f4f24-5d8f-4f80-8cbb-0a9d776312b2         1
# fallback_artist::abie rotenberg              1
# 26f62bfe-2bf3-4181-bb71-7cacd8222465         1
# 989e5860-2837-4add-9814-668cb25f6f1e         1
# fallback_artist::i create                    1
# fallback_artist::seth stewart                1
# 1acaadc8-53e7-4e28-bca0-a7a0915bb15a         2
# 4b96aeb8-db1a-45b0-b665-ab24858408af         2
# fallback_artist::don vilanova botafogo       1
# fallback_artist::roonin                      1
# fallback_artist::secret clubhouse            1
# ca4231dc-68aa-4b5c-b16d-22aa418c281d         1
# fallback_artist::agraceful                   1
# fallback_artist::joel shearer                1
# fallback_artist::yung aeon                   2
# Track - 7d: Top 20 predicted
#   Hit rate: 100.0%
#   Test-set prevalence: 35.9%
#   Lift vs random baseline: 2.78x
#                                                     mean_xgb_score  \
# recording_id
# fallback::motionless in white||afraid of the da...          0.9067
# fallback::john michael howell||a thousand years...          0.9067
# fallback::bleachers||you and forever||you and f...          0.9053
# fallback::hemlocke springs||be the girl!||the a...          0.9039
# fallback::femtanyl||act right||act right                    0.9039
# fallback::femtanyl||body the pistol||man bites dog          0.9039
# fallback::charli xcx||my reminder||wuthering he...          0.9039
# fallback::charli xcx||funny mouth||wuthering he...          0.9039
# fallback::charli xcx||dying for you||wuthering ...          0.9018
# fallback::charli xcx||wall of sound||wuthering ...          0.8900
# fallback::wet leg||mangetout - the dare remix||...          0.8824
# fallback::marcin pukaluk||chilling out in the h...          0.8794
# fallback::j. cole||two six||the fall-off                    0.8766
# fallback::vana||pray||pray                                  0.8741
# fallback::the warning||love to be loved||love t...          0.8701
# fallback::don toliver||excavator||octane                    0.8635
# fallback::converge||make me forget you||love is...          0.8591
# fallback::angine de poitrine||tamebsz||vol.1                0.8581
# fallback::joji||can't see sh*t in the club||pis...          0.8557
# fallback::danny l harle||two hearts||cerulean               0.8430
#
#                                                     actually_popular  n_days
# recording_id
# fallback::motionless in white||afraid of the da...                 1       1
# fallback::john michael howell||a thousand years...                 1       1
# fallback::bleachers||you and forever||you and f...                 1       1
# fallback::hemlocke springs||be the girl!||the a...                 1       1
# fallback::femtanyl||act right||act right                           1       1
# fallback::femtanyl||body the pistol||man bites dog                 1       1
# fallback::charli xcx||my reminder||wuthering he...                 1       1
# fallback::charli xcx||funny mouth||wuthering he...                 1       1
# fallback::charli xcx||dying for you||wuthering ...                 1       1
# fallback::charli xcx||wall of sound||wuthering ...                 1       1
# fallback::wet leg||mangetout - the dare remix||...                 1       2
# fallback::marcin pukaluk||chilling out in the h...                 1       1
# fallback::j. cole||two six||the fall-off                           1       2
# fallback::vana||pray||pray                                         1       1
# fallback::the warning||love to be loved||love t...                 1       1
# fallback::don toliver||excavator||octane                           1       1
# fallback::converge||make me forget you||love is...                 1       1
# fallback::angine de poitrine||tamebsz||vol.1                       1       1
# fallback::joji||can't see sh*t in the club||pis...                 1       1
# fallback::danny l harle||two hearts||cerulean                      1       1
# Track - 30d: Top 20 predicted
#   Hit rate: 100.0%
#   Test-set prevalence: 35.9%
#   Lift vs random baseline: 2.78x
#                                                     mean_xgb_score  \
# recording_id
# fallback::motionless in white||afraid of the da...          0.9103
# fallback::john michael howell||a thousand years...          0.9042
# fallback::hemlocke springs||be the girl!||the a...          0.8937
# fallback::charli xcx||my reminder||wuthering he...          0.8937
# fallback::femtanyl||act right||act right                    0.8937
# fallback::femtanyl||body the pistol||man bites dog          0.8937
# fallback::charli xcx||funny mouth||wuthering he...          0.8937
# fallback::charli xcx||dying for you||wuthering ...          0.8902
# fallback::bleachers||you and forever||you and f...          0.8891
# fallback::charli xcx||wall of sound||wuthering ...          0.8851
# fallback::j. cole||two six||the fall-off                    0.8833
# fallback::marcin pukaluk||chilling out in the h...          0.8825
# fallback::wet leg||mangetout - the dare remix||...          0.8740
# fallback::the warning||love to be loved||love t...          0.8731
# fallback::vana||pray||pray                                  0.8710
# fallback::angine de poitrine||tamebsz||vol.1                0.8577
# fallback::don toliver||excavator||octane                    0.8489
# fallback::danny l harle||two hearts||cerulean               0.8475
# fallback::joji||can't see sh*t in the club||pis...          0.8469
# fallback::geese||gravity blues||3d country                  0.8359
#
#                                                     actually_popular  n_days
# recording_id
# fallback::motionless in white||afraid of the da...                 1       1
# fallback::john michael howell||a thousand years...                 1       1
# fallback::hemlocke springs||be the girl!||the a...                 1       1
# fallback::charli xcx||my reminder||wuthering he...                 1       1
# fallback::femtanyl||act right||act right                           1       1
# fallback::femtanyl||body the pistol||man bites dog                 1       1
# fallback::charli xcx||funny mouth||wuthering he...                 1       1
# fallback::charli xcx||dying for you||wuthering ...                 1       1
# fallback::bleachers||you and forever||you and f...                 1       1
# fallback::charli xcx||wall of sound||wuthering ...                 1       1
# fallback::j. cole||two six||the fall-off                           1       2
# fallback::marcin pukaluk||chilling out in the h...                 1       1
# fallback::wet leg||mangetout - the dare remix||...                 1       2
# fallback::the warning||love to be loved||love t...                 1       1
# fallback::vana||pray||pray                                         1       1
# fallback::angine de poitrine||tamebsz||vol.1                       1       1
# fallback::don toliver||excavator||octane                           1       1
# fallback::danny l harle||two hearts||cerulean                      1       1
# fallback::joji||can't see sh*t in the club||pis...                 1       1
# fallback::geese||gravity blues||3d country                         1       1

# %% [markdown]
# ### Time Series Visualization: Top 20 Predicted Tracks (30d Model)
#
# Visualize actual listen counts over time for the top 20 tracks predicted by the **XGBoost track 30d classifier**, showing:
# - Historical trajectory (last ~2 months of training window)
# - Actual performance in test window
# - Model predictions for popularity (XGBoost classifier + regressor)

# %%
# Select top 20 tracks by predicted score from the track 30d classifier
TOP_K_PLOTS = 20

track_30d_proba = xgb_results[("track", "30d", "clf")][2]
track_30d_reg = xgb_results[("track", "30d", "reg")][2]

trk_test_with_preds = trk_test.copy()
trk_test_with_preds["xgb_30d_clf_score"] = track_30d_proba
trk_test_with_preds["xgb_30d_reg_pred"] = track_30d_reg

# Aggregate per track and pick top 20 by mean predicted 30d popularity score
top_tracks_df = (
    trk_test_with_preds
    .groupby("recording_id")
    .agg(
        mean_xgb_30d_score=("xgb_30d_clf_score", "mean"),
        mean_xgb_30d_reg=("xgb_30d_reg_pred", "mean"),
        actually_popular_30d=("is_popular_30d", "max"),
        n_test_days=("day", "count"),
    )
    .sort_values("mean_xgb_30d_score", ascending=False)
    .head(TOP_K_PLOTS)
)
top_tracks = top_tracks_df.index.tolist()

print("Top 20 tracks selected by mean XGB 30d classifier score:")
print(top_tracks_df[["mean_xgb_30d_score", "actually_popular_30d", "n_test_days"]].round(4))

# Time boundaries
train_max_day = trk_train["day"].max()
test_min_day = trk_test["day"].min()
test_max_day = trk_test["day"].max()
history_start = train_max_day - pd.Timedelta(days=60)

print(f"\nTrain/test split: {train_max_day}")
print(f"Test window: {test_min_day} to {test_max_day}")
print(f"Showing training data from: {history_start} onwards")

# Plot as 5x4 grid (20 tracks)
nrows, ncols = 5, 4
fig, axes = plt.subplots(nrows, ncols, figsize=(24, 20), sharex=False)
axes = axes.flatten()
fig.suptitle(
    "Top 20 Predicted Tracks (XGB 30d): Listen Counts (Last 2 Months + Test Window)",
    fontsize=18,
    y=0.995,
)

for idx, track_id in enumerate(top_tracks):
    ax = axes[idx]

    # Historical data (last ~2 months before split)
    track_train = (
        trk_train[
            (trk_train["recording_id"] == track_id)
            & (trk_train["day"] >= history_start)
        ]
        .sort_values("day")
    )

    # Test data with predictions
    track_test = (
        trk_test_with_preds[trk_test_with_preds["recording_id"] == track_id]
        .sort_values("day")
    )

    if len(track_train) > 0:
        ax.plot(
            track_train["day"],
            track_train["listen_count"],
            color="steelblue",
            linewidth=1.4,
            marker="o",
            markersize=2.5,
            label="Historical (last 2 months)",
        )

    if len(track_test) > 0:
        ax.plot(
            track_test["day"],
            track_test["listen_count"],
            color="forestgreen",
            linewidth=1.8,
            marker="s",
            markersize=3,
            label="Actual (test)",
        )

    ax.axvline(
        train_max_day,
        color="red",
        linestyle="--",
        linewidth=1.2,
        alpha=0.75,
        label="Train/Test Split",
    )

    # Annotation with model summary for this track
    stats = top_tracks_df.loc[track_id]
    pred_text = (
        f"30d clf: {stats['mean_xgb_30d_score']:.3f}\n"
        f"30d reg: {stats['mean_xgb_30d_reg']:.3f}\n"
        f"Actual popular: {'Yes' if int(stats['actually_popular_30d']) == 1 else 'No'}"
    )
    ax.text(
        0.02,
        0.02,
        pred_text,
        transform=ax.transAxes,
        fontsize=8,
        va="bottom",
        bbox=dict(boxstyle="round", facecolor="wheat", alpha=0.5),
    )

    track_display = track_id if len(track_id) <= 45 else track_id[:42] + "..."
    ax.set_title(f"#{idx+1} {track_display}", fontsize=9, loc="left")
    ax.set_ylabel("Daily Listens", fontsize=8)
    ax.tick_params(axis="x", rotation=45, labelsize=7)
    ax.tick_params(axis="y", labelsize=7)
    ax.grid(True, alpha=0.25)

    # Keep legend only on first panel to reduce clutter
    if idx == 0:
        ax.legend(loc="upper left", fontsize=8, framealpha=0.9)

# Hide any unused axes (defensive)
for j in range(len(top_tracks), len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()

print("\nVisualization complete for top 20 predicted tracks (30d model).")
# Out:
# Top 20 tracks selected by mean XGB 30d classifier score:
#                                                     mean_xgb_30d_score  \
# recording_id
# fallback::motionless in white||afraid of the da...              0.9103
# fallback::john michael howell||a thousand years...              0.9042
# fallback::hemlocke springs||be the girl!||the a...              0.8937
# fallback::charli xcx||my reminder||wuthering he...              0.8937
# fallback::femtanyl||act right||act right                        0.8937
# fallback::femtanyl||body the pistol||man bites dog              0.8937
# fallback::charli xcx||funny mouth||wuthering he...              0.8937
# fallback::charli xcx||dying for you||wuthering ...              0.8902
# fallback::bleachers||you and forever||you and f...              0.8891
# fallback::charli xcx||wall of sound||wuthering ...              0.8851
# fallback::j. cole||two six||the fall-off                        0.8833
# fallback::marcin pukaluk||chilling out in the h...              0.8825
# fallback::wet leg||mangetout - the dare remix||...              0.8740
# fallback::the warning||love to be loved||love t...              0.8731
# fallback::vana||pray||pray                                      0.8710
# fallback::angine de poitrine||tamebsz||vol.1                    0.8577
# fallback::don toliver||excavator||octane                        0.8489
# fallback::danny l harle||two hearts||cerulean                   0.8475
# fallback::joji||can't see sh*t in the club||pis...              0.8469
# fallback::geese||gravity blues||3d country                      0.8359
#
#                                                     actually_popular_30d  \
# recording_id
# fallback::motionless in white||afraid of the da...                     1
# fallback::john michael howell||a thousand years...                     1
# fallback::hemlocke springs||be the girl!||the a...                     1
# fallback::charli xcx||my reminder||wuthering he...                     1
# fallback::femtanyl||act right||act right                               1
# fallback::femtanyl||body the pistol||man bites dog                     1
# fallback::charli xcx||funny mouth||wuthering he...                     1
# fallback::charli xcx||dying for you||wuthering ...                     1
# fallback::bleachers||you and forever||you and f...                     1
# fallback::charli xcx||wall of sound||wuthering ...                     1
# fallback::j. cole||two six||the fall-off                               1
# fallback::marcin pukaluk||chilling out in the h...                     1
# fallback::wet leg||mangetout - the dare remix||...                     1
# fallback::the warning||love to be loved||love t...                     1
# fallback::vana||pray||pray                                             1
# fallback::angine de poitrine||tamebsz||vol.1                           1
# fallback::don toliver||excavator||octane                               1
# fallback::danny l harle||two hearts||cerulean                          1
# fallback::joji||can't see sh*t in the club||pis...                     1
# fallback::geese||gravity blues||3d country                             1
#
#                                                     n_test_days
# recording_id
# fallback::motionless in white||afraid of the da...            1
# fallback::john michael howell||a thousand years...            1
# fallback::hemlocke springs||be the girl!||the a...            1
# fallback::charli xcx||my reminder||wuthering he...            1
# fallback::femtanyl||act right||act right                      1
# fallback::femtanyl||body the pistol||man bites dog            1
# fallback::charli xcx||funny mouth||wuthering he...            1
# fallback::charli xcx||dying for you||wuthering ...            1
# fallback::bleachers||you and forever||you and f...            1
# fallback::charli xcx||wall of sound||wuthering ...            1
# fallback::j. cole||two six||the fall-off                      2
# fallback::marcin pukaluk||chilling out in the h...            1
# fallback::wet leg||mangetout - the dare remix||...            2
# fallback::the warning||love to be loved||love t...            1
# fallback::vana||pray||pray                                    1
# fallback::angine de poitrine||tamebsz||vol.1                  1
# fallback::don toliver||excavator||octane                      1
# fallback::danny l harle||two hearts||cerulean                 1
# fallback::joji||can't see sh*t in the club||pis...            1
# fallback::geese||gravity blues||3d country                    1
#
# Train/test split: 2026-02-15 00:00:00
# Test window: 2026-02-16 00:00:00 to 2026-02-18 00:00:00
# Showing training data from: 2025-12-17 00:00:00 onwards
# Visualization complete for top 20 predicted tracks (30d model).

# %% [markdown]
# ## Detailed Prediction Analysis & Visualizations
#
# Focused diagnostics across all trained models:
# - **Regression** — per-track actual vs predicted listening percentile over the test window
# - **Classifier** — top-20 predicted entities table with TP/FP labels
# - **Aggregated trend** — daily mean predicted vs actual (classifier + regressor, all horizons)
# - **Rolling listens** — 7-day and 30-day listen count trajectories for the top 20 predicted tracks

# %%
# ── Regression: top-20 tracks — actual vs predicted listening percentile ───────
# For each of the top 20 tracks (ranked by XGB 30d classifier score) show the
# actual future_growth_pctl_30d alongside the model's predicted percentile over
# the full test window.  One subplot per track, 5×4 grid.

_reg_target = "future_growth_pctl_30d"

_nrows, _ncols = 5, 4
fig, axes = plt.subplots(_nrows, _ncols, figsize=(24, 20), sharex=False)
axes = axes.flatten()
fig.suptitle(
    "Top 20 Predicted Tracks – Actual vs Predicted Listening Percentile (XGB 30d Regressor)",
    fontsize=14,
    y=1.002,
)

for idx, track_id in enumerate(top_tracks):
    ax = axes[idx]
    td = (
        trk_test_with_preds[trk_test_with_preds["recording_id"] == track_id]
        .sort_values("day")
        .copy()
    )

    if len(td) > 0 and _reg_target in td.columns:
        ax.plot(
            td["day"],
            td[_reg_target],
            color="steelblue",
            linewidth=1.6,
            marker="o",
            markersize=3,
            label="Actual",
        )
        ax.plot(
            td["day"],
            td["xgb_30d_reg_pred"].clip(0, 1),
            color="darkorange",
            linewidth=1.6,
            linestyle="--",
            marker="s",
            markersize=3,
            label="Predicted",
        )
        ax.axhline(
            0.95, color="red", linestyle=":", linewidth=1.0, alpha=0.55,
            label="Popular (0.95)"
        )
    else:
        ax.text(0.5, 0.5, "No test data", ha="center", va="center",
                transform=ax.transAxes, fontsize=9)

    _display_id = track_id if len(track_id) <= 38 else track_id[:35] + "..."
    ax.set_title(f"#{idx + 1}  {_display_id}", fontsize=8, loc="left")
    ax.set_ylim(-0.05, 1.05)
    ax.set_ylabel("Percentile", fontsize=7)
    ax.tick_params(axis="x", rotation=45, labelsize=6)
    ax.tick_params(axis="y", labelsize=7)
    ax.grid(True, alpha=0.25)
    if idx == 0:
        ax.legend(fontsize=7, framealpha=0.9)

for j in range(len(top_tracks), len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
print("Regression actual vs predicted percentile — complete.")
# Out:
# Regression actual vs predicted percentile — complete.

# %%
# ── Predicted vs Actual: daily aggregated trend — all models ──────────────────
# Aggregates all test rows by day.  For each (entity, horizon) pair shows:
#   • Left panel: classifier — daily fraction actually popular vs mean predicted score
#   • Right panel: regressor — daily mean actual percentile vs mean predicted percentile
# A flat predicted line alongside a moving actual line reveals systematic bias;
# a well-calibrated model should track the actual curve closely.

for entity, train_df, test_df, feat_cols in configs:
    id_col = "artist_id" if entity == "artist" else "recording_id"

    fig, axes = plt.subplots(2, 2, figsize=(18, 10))
    fig.suptitle(
        f"Predicted vs Actual — Daily Aggregated Trend  ·  {entity.title()}",
        fontsize=13,
    )

    for row, horizon in enumerate(["7d", "30d"]):
        clf_key = (entity, horizon, "clf")
        reg_key = (entity, horizon, "reg")

        # ── Classifier: fraction popular vs mean predicted score ──────────────
        ax_clf = axes[row][0]
        clf_entry = xgb_results.get(clf_key)
        if clf_entry is not None and clf_entry[0] is not None and len(clf_entry[2]):
            clf_target = f"is_popular_{horizon}"
            _tmp = test_df[[id_col, "day", clf_target]].copy()
            _tmp["pred_score"] = clf_entry[2]
            _daily = (
                _tmp.groupby("day")
                .agg(
                    mean_actual=(clf_target, "mean"),
                    mean_pred=("pred_score", "mean"),
                )
                .reset_index()
                .sort_values("day")
            )
            ax_clf.plot(
                _daily["day"], _daily["mean_actual"],
                linewidth=2, marker="o", markersize=3,
                color="steelblue", label="Actual (fraction popular)"
            )
            ax_clf.plot(
                _daily["day"], _daily["mean_pred"],
                linewidth=2, linestyle="--", marker="s", markersize=3,
                color="darkorange", label="Mean predicted score"
            )
            ax_clf.set_title(f"Classifier {horizon}", fontsize=10)
            ax_clf.set_ylabel("Score / fraction popular")
            ax_clf.legend(fontsize=8)
        else:
            ax_clf.text(0.5, 0.5, f"No classifier\n{entity} {horizon}",
                        ha="center", va="center", transform=ax_clf.transAxes)
        ax_clf.tick_params(axis="x", rotation=35, labelsize=8)
        ax_clf.grid(True, alpha=0.25)

        # ── Regressor: actual vs predicted percentile ─────────────────────────
        ax_reg = axes[row][1]
        reg_entry = xgb_results.get(reg_key)
        if reg_entry is not None and reg_entry[0] is not None and len(reg_entry[2]):
            reg_target = f"future_growth_pctl_{horizon}"
            _tmp = test_df[[id_col, "day", reg_target]].copy()
            _tmp["pred_pctl"] = np.clip(reg_entry[2], 0, 1)
            _daily = (
                _tmp.groupby("day")
                .agg(
                    mean_actual=(reg_target, "mean"),
                    mean_pred=("pred_pctl", "mean"),
                )
                .reset_index()
                .sort_values("day")
            )
            ax_reg.plot(
                _daily["day"], _daily["mean_actual"],
                linewidth=2, marker="o", markersize=3,
                color="steelblue", label="Actual percentile"
            )
            ax_reg.plot(
                _daily["day"], _daily["mean_pred"],
                linewidth=2, linestyle="--", marker="s", markersize=3,
                color="darkorange", label="Predicted percentile"
            )
            ax_reg.set_title(f"Regressor {horizon}", fontsize=10)
            ax_reg.set_ylabel("Percentile (0–1)")
            ax_reg.legend(fontsize=8)
        else:
            ax_reg.text(0.5, 0.5, f"No regressor\n{entity} {horizon}",
                        ha="center", va="center", transform=ax_reg.transAxes)
        ax_reg.tick_params(axis="x", rotation=35, labelsize=8)
        ax_reg.grid(True, alpha=0.25)

    plt.tight_layout()
    plt.show()

print("Aggregated daily trend plots — complete.")
# Out:
# Aggregated daily trend plots — complete.

# %%
# ── Classifier: top-20 predicted entities — styled summary table ──────────────
# For every (entity, horizon) combination with a trained XGB classifier, rank
# all test entities by their mean predicted score and show the top 20 with:
#   • predicted score, predicted label, actual label
#   • ✓ TP / ✓ TN / ✗ FP / ✗ FN result (colour-coded)
#   • day-level accuracy fraction
# Hit rate, prevalence, and lift vs random are printed above each table.

def _result_style(val):
    """Row-level background for TP/TN/FP/FN result column."""
    if isinstance(val, str):
        if val.startswith("✓ TP"):
            return "background-color:#d4edda; color:#155724"
        if val.startswith("✓ TN"):
            return "background-color:#cce5ff; color:#004085"
        if val.startswith("✗ FP"):
            return "background-color:#fff3cd; color:#856404"
        if val.startswith("✗ FN"):
            return "background-color:#f8d7da; color:#721c24"
    return ""

for entity, _, test_df, feat_cols in configs:
    id_col = "artist_id" if entity == "artist" else "recording_id"

    for horizon in ["7d", "30d"]:
        clf_key = (entity, horizon, "clf")
        clf_entry = xgb_results.get(clf_key)
        if clf_entry is None or clf_entry[0] is None or not len(clf_entry[2]):
            print(f"No classifier stored for {entity} {horizon} — skipping table.")
            continue

        clf_target = f"is_popular_{horizon}"
        clf_metrics = clf_entry[1]
        threshold = clf_metrics.get("decision_threshold", 0.5)

        _tmp = test_df[[id_col, "day", clf_target]].copy()
        _tmp["pred_score"] = clf_entry[2]
        _tmp["pred_label"] = (_tmp["pred_score"] >= threshold).astype(int)
        _tmp["day_correct"] = (_tmp["pred_label"] == _tmp[clf_target]).astype(int)

        top20 = (
            _tmp.groupby(id_col)
            .agg(
                avg_pred_score=("pred_score", "mean"),
                pred_popular=("pred_label", "max"),
                actually_popular=(clf_target, "max"),
                day_accuracy=("day_correct", "mean"),
                n_test_days=("day", "count"),
            )
            .sort_values("avg_pred_score", ascending=False)
            .head(20)
            .reset_index()
        )

        top20["result"] = top20.apply(
            lambda r: (
                "✓ TP" if r["pred_popular"] == 1 and r["actually_popular"] == 1
                else "✗ FP" if r["pred_popular"] == 1 and r["actually_popular"] == 0
                else "✓ TN" if r["pred_popular"] == 0 and r["actually_popular"] == 0
                else "✗ FN"
            ),
            axis=1,
        )

        hit_rate = top20["actually_popular"].mean()
        prevalence = float(test_df[clf_target].mean())
        lift = (hit_rate / prevalence) if prevalence > 0 else float("nan")

        print(f"\n{'='*68}")
        print(
            f"  Classifier Top-20  ·  {entity.title()} — {horizon}"
            f"  |  threshold={threshold:.3f}"
        )
        print(
            f"  Hit rate: {100*hit_rate:.1f}%  |  "
            f"Test prevalence: {100*prevalence:.1f}%  |  "
            f"Lift vs random: {lift:.2f}x"
        )
        print(f"{'='*68}")

        display(
            top20.rename(columns={
                id_col: "Entity ID",
                "avg_pred_score": "Pred Score",
                "pred_popular": "Pred Popular",
                "actually_popular": "Actually Popular",
                "result": "Result",
                "day_accuracy": "Day Accuracy",
                "n_test_days": "# Days",
            })
            .round(4)
            .style
            .map(_result_style, subset=["Result"])
            .background_gradient(subset=["Pred Score"], cmap="YlOrRd")
            .format({"Pred Score": "{:.4f}", "Day Accuracy": "{:.2%}"})
        )

print("\nClassifier top-20 tables — complete.")
# Out:
# ====================================================================
#   Classifier Top-20  ·  Artist — 7d  |  threshold=0.800
#   Hit rate: 100.0%  |  Test prevalence: 2.6%  |  Lift vs random: 38.84x
# ====================================================================
# <style type="text/css">
# #T_e0ca3_row0_col1, #T_e0ca3_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e0ca3_row0_col6, #T_e0ca3_row1_col6, #T_e0ca3_row2_col6, #T_e0ca3_row3_col6, #T_e0ca3_row4_col6, #T_e0ca3_row5_col6, #T_e0ca3_row6_col6, #T_e0ca3_row7_col6, #T_e0ca3_row8_col6, #T_e0ca3_row9_col6, #T_e0ca3_row10_col6, #T_e0ca3_row11_col6, #T_e0ca3_row12_col6, #T_e0ca3_row13_col6, #T_e0ca3_row14_col6, #T_e0ca3_row15_col6, #T_e0ca3_row16_col6, #T_e0ca3_row17_col6, #T_e0ca3_row18_col6, #T_e0ca3_row19_col6 {
#   background-color: #d4edda;
#   color: #155724;
# }
# #T_e0ca3_row2_col1 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_e0ca3_row3_col1 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_e0ca3_row4_col1, #T_e0ca3_row5_col1, #T_e0ca3_row6_col1, #T_e0ca3_row7_col1, #T_e0ca3_row8_col1 {
#   background-color: #fd7636;
#   color: #f1f1f1;
# }
# #T_e0ca3_row9_col1, #T_e0ca3_row10_col1, #T_e0ca3_row11_col1 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_e0ca3_row12_col1 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_e0ca3_row13_col1 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_e0ca3_row14_col1 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_e0ca3_row15_col1, #T_e0ca3_row16_col1, #T_e0ca3_row17_col1, #T_e0ca3_row18_col1, #T_e0ca3_row19_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_e0ca3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0ca3_level0_col0" class="col_heading level0 col0" >Entity ID</th>
#       <th id="T_e0ca3_level0_col1" class="col_heading level0 col1" >Pred Score</th>
#       <th id="T_e0ca3_level0_col2" class="col_heading level0 col2" >Pred Popular</th>
#       <th id="T_e0ca3_level0_col3" class="col_heading level0 col3" >Actually Popular</th>
#       <th id="T_e0ca3_level0_col4" class="col_heading level0 col4" >Day Accuracy</th>
#       <th id="T_e0ca3_level0_col5" class="col_heading level0 col5" ># Days</th>
#       <th id="T_e0ca3_level0_col6" class="col_heading level0 col6" >Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0ca3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0ca3_row0_col0" class="data row0 col0" >4b96aeb8-db1a-45b0-b665-ab24858408af</td>
#       <td id="T_e0ca3_row0_col1" class="data row0 col1" >0.9209</td>
#       <td id="T_e0ca3_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_e0ca3_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_e0ca3_row0_col4" class="data row0 col4" >50.00%</td>
#       <td id="T_e0ca3_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_e0ca3_row0_col6" class="data row0 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0ca3_row1_col0" class="data row1 col0" >1acaadc8-53e7-4e28-bca0-a7a0915bb15a</td>
#       <td id="T_e0ca3_row1_col1" class="data row1 col1" >0.9209</td>
#       <td id="T_e0ca3_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_e0ca3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_e0ca3_row1_col4" class="data row1 col4" >100.00%</td>
#       <td id="T_e0ca3_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_e0ca3_row1_col6" class="data row1 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0ca3_row2_col0" class="data row2 col0" >fallback_artist::jambinai</td>
#       <td id="T_e0ca3_row2_col1" class="data row2 col1" >0.9201</td>
#       <td id="T_e0ca3_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_e0ca3_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_e0ca3_row2_col4" class="data row2 col4" >100.00%</td>
#       <td id="T_e0ca3_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_e0ca3_row2_col6" class="data row2 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0ca3_row3_col0" class="data row3 col0" >fallback_artist::quartz</td>
#       <td id="T_e0ca3_row3_col1" class="data row3 col1" >0.9165</td>
#       <td id="T_e0ca3_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_e0ca3_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_e0ca3_row3_col4" class="data row3 col4" >100.00%</td>
#       <td id="T_e0ca3_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_e0ca3_row3_col6" class="data row3 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0ca3_row4_col0" class="data row4 col0" >26f62bfe-2bf3-4181-bb71-7cacd8222465</td>
#       <td id="T_e0ca3_row4_col1" class="data row4 col1" >0.9151</td>
#       <td id="T_e0ca3_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_e0ca3_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_e0ca3_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_e0ca3_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_e0ca3_row4_col6" class="data row4 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0ca3_row5_col0" class="data row5 col0" >fallback_artist::i create</td>
#       <td id="T_e0ca3_row5_col1" class="data row5 col1" >0.9151</td>
#       <td id="T_e0ca3_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_e0ca3_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_e0ca3_row5_col4" class="data row5 col4" >100.00%</td>
#       <td id="T_e0ca3_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_e0ca3_row5_col6" class="data row5 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0ca3_row6_col0" class="data row6 col0" >980f4f24-5d8f-4f80-8cbb-0a9d776312b2</td>
#       <td id="T_e0ca3_row6_col1" class="data row6 col1" >0.9151</td>
#       <td id="T_e0ca3_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_e0ca3_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_e0ca3_row6_col4" class="data row6 col4" >100.00%</td>
#       <td id="T_e0ca3_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_e0ca3_row6_col6" class="data row6 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e0ca3_row7_col0" class="data row7 col0" >989e5860-2837-4add-9814-668cb25f6f1e</td>
#       <td id="T_e0ca3_row7_col1" class="data row7 col1" >0.9151</td>
#       <td id="T_e0ca3_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_e0ca3_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_e0ca3_row7_col4" class="data row7 col4" >100.00%</td>
#       <td id="T_e0ca3_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_e0ca3_row7_col6" class="data row7 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e0ca3_row8_col0" class="data row8 col0" >fallback_artist::abie rotenberg</td>
#       <td id="T_e0ca3_row8_col1" class="data row8 col1" >0.9151</td>
#       <td id="T_e0ca3_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_e0ca3_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_e0ca3_row8_col4" class="data row8 col4" >100.00%</td>
#       <td id="T_e0ca3_row8_col5" class="data row8 col5" >1</td>
#       <td id="T_e0ca3_row8_col6" class="data row8 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e0ca3_row9_col0" class="data row9 col0" >fallback_artist::agraceful</td>
#       <td id="T_e0ca3_row9_col1" class="data row9 col1" >0.9144</td>
#       <td id="T_e0ca3_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_e0ca3_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_e0ca3_row9_col4" class="data row9 col4" >100.00%</td>
#       <td id="T_e0ca3_row9_col5" class="data row9 col5" >1</td>
#       <td id="T_e0ca3_row9_col6" class="data row9 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_e0ca3_level0_row10" class="row_heading level0 row10" >10</t
# ====================================================================
#   Classifier Top-20  ·  Artist — 30d  |  threshold=0.800
#   Hit rate: 100.0%  |  Test prevalence: 2.6%  |  Lift vs random: 38.84x
# ====================================================================
# <style type="text/css">
# #T_d08c8_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_d08c8_row0_col6, #T_d08c8_row1_col6, #T_d08c8_row2_col6, #T_d08c8_row3_col6, #T_d08c8_row4_col6, #T_d08c8_row5_col6, #T_d08c8_row6_col6, #T_d08c8_row7_col6, #T_d08c8_row8_col6, #T_d08c8_row9_col6, #T_d08c8_row10_col6, #T_d08c8_row11_col6, #T_d08c8_row12_col6, #T_d08c8_row13_col6, #T_d08c8_row14_col6, #T_d08c8_row15_col6, #T_d08c8_row16_col6, #T_d08c8_row17_col6, #T_d08c8_row18_col6, #T_d08c8_row19_col6 {
#   background-color: #d4edda;
#   color: #155724;
# }
# #T_d08c8_row1_col1 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_d08c8_row2_col1 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_d08c8_row3_col1 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_d08c8_row4_col1 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_d08c8_row5_col1, #T_d08c8_row6_col1, #T_d08c8_row7_col1, #T_d08c8_row8_col1, #T_d08c8_row9_col1 {
#   background-color: #fc6c33;
#   color: #f1f1f1;
# }
# #T_d08c8_row10_col1 {
#   background-color: #fd8439;
#   color: #f1f1f1;
# }
# #T_d08c8_row11_col1, #T_d08c8_row12_col1 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_d08c8_row13_col1 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_d08c8_row14_col1 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_d08c8_row15_col1, #T_d08c8_row16_col1, #T_d08c8_row17_col1 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_d08c8_row18_col1 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_d08c8_row19_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_d08c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d08c8_level0_col0" class="col_heading level0 col0" >Entity ID</th>
#       <th id="T_d08c8_level0_col1" class="col_heading level0 col1" >Pred Score</th>
#       <th id="T_d08c8_level0_col2" class="col_heading level0 col2" >Pred Popular</th>
#       <th id="T_d08c8_level0_col3" class="col_heading level0 col3" >Actually Popular</th>
#       <th id="T_d08c8_level0_col4" class="col_heading level0 col4" >Day Accuracy</th>
#       <th id="T_d08c8_level0_col5" class="col_heading level0 col5" ># Days</th>
#       <th id="T_d08c8_level0_col6" class="col_heading level0 col6" >Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d08c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d08c8_row0_col0" class="data row0 col0" >fallback_artist::jambinai</td>
#       <td id="T_d08c8_row0_col1" class="data row0 col1" >0.9344</td>
#       <td id="T_d08c8_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_d08c8_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_d08c8_row0_col4" class="data row0 col4" >100.00%</td>
#       <td id="T_d08c8_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_d08c8_row0_col6" class="data row0 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d08c8_row1_col0" class="data row1 col0" >fallback_artist::キング</td>
#       <td id="T_d08c8_row1_col1" class="data row1 col1" >0.9255</td>
#       <td id="T_d08c8_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_d08c8_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_d08c8_row1_col4" class="data row1 col4" >100.00%</td>
#       <td id="T_d08c8_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_d08c8_row1_col6" class="data row1 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d08c8_row2_col0" class="data row2 col0" >fallback_artist::rolobi</td>
#       <td id="T_d08c8_row2_col1" class="data row2 col1" >0.9216</td>
#       <td id="T_d08c8_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_d08c8_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_d08c8_row2_col4" class="data row2 col4" >100.00%</td>
#       <td id="T_d08c8_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_d08c8_row2_col6" class="data row2 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d08c8_row3_col0" class="data row3 col0" >fallback_artist::quartz</td>
#       <td id="T_d08c8_row3_col1" class="data row3 col1" >0.9213</td>
#       <td id="T_d08c8_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_d08c8_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_d08c8_row3_col4" class="data row3 col4" >100.00%</td>
#       <td id="T_d08c8_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_d08c8_row3_col6" class="data row3 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d08c8_row4_col0" class="data row4 col0" >fallback_artist::サロン</td>
#       <td id="T_d08c8_row4_col1" class="data row4 col1" >0.9142</td>
#       <td id="T_d08c8_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_d08c8_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_d08c8_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_d08c8_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_d08c8_row4_col6" class="data row4 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d08c8_row5_col0" class="data row5 col0" >980f4f24-5d8f-4f80-8cbb-0a9d776312b2</td>
#       <td id="T_d08c8_row5_col1" class="data row5 col1" >0.9113</td>
#       <td id="T_d08c8_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_d08c8_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_d08c8_row5_col4" class="data row5 col4" >100.00%</td>
#       <td id="T_d08c8_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_d08c8_row5_col6" class="data row5 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d08c8_row6_col0" class="data row6 col0" >fallback_artist::abie rotenberg</td>
#       <td id="T_d08c8_row6_col1" class="data row6 col1" >0.9113</td>
#       <td id="T_d08c8_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_d08c8_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_d08c8_row6_col4" class="data row6 col4" >100.00%</td>
#       <td id="T_d08c8_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_d08c8_row6_col6" class="data row6 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d08c8_row7_col0" class="data row7 col0" >26f62bfe-2bf3-4181-bb71-7cacd8222465</td>
#       <td id="T_d08c8_row7_col1" class="data row7 col1" >0.9113</td>
#       <td id="T_d08c8_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_d08c8_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_d08c8_row7_col4" class="data row7 col4" >100.00%</td>
#       <td id="T_d08c8_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_d08c8_row7_col6" class="data row7 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d08c8_row8_col0" class="data row8 col0" >989e5860-2837-4add-9814-668cb25f6f1e</td>
#       <td id="T_d08c8_row8_col1" class="data row8 col1" >0.9113</td>
#       <td id="T_d08c8_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_d08c8_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_d08c8_row8_col4" class="data row8 col4" >100.00%</td>
#       <td id="T_d08c8_row8_col5" class="data row8 col5" >1</td>
#       <td id="T_d08c8_row8_col6" class="data row8 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_d08c8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d08c8_row9_col0" class="data row9 col0" >fallback_artist::i create</td>
#       <td id="T_d08c8_row9_col1" class="data row9 col1" >0.9113</td>
#       <td id="T_d08c8_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_d08c8_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_d08c8_row9_col4" class="data row9 col4" >100.00%</td>
#       <td id="T_d08c8_row9_col5" class="data row9 col5" >1<
# ====================================================================
#   Classifier Top-20  ·  Track — 7d  |  threshold=0.500
#   Hit rate: 100.0%  |  Test prevalence: 35.9%  |  Lift vs random: 2.78x
# ====================================================================
# <style type="text/css">
# #T_15673_row0_col1, #T_15673_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_15673_row0_col6, #T_15673_row1_col6, #T_15673_row2_col6, #T_15673_row3_col6, #T_15673_row4_col6, #T_15673_row5_col6, #T_15673_row6_col6, #T_15673_row7_col6, #T_15673_row8_col6, #T_15673_row9_col6, #T_15673_row10_col6, #T_15673_row11_col6, #T_15673_row12_col6, #T_15673_row13_col6, #T_15673_row14_col6, #T_15673_row15_col6, #T_15673_row16_col6, #T_15673_row17_col6, #T_15673_row18_col6, #T_15673_row19_col6 {
#   background-color: #d4edda;
#   color: #155724;
# }
# #T_15673_row2_col1 {
#   background-color: #8a0026;
#   color: #f1f1f1;
# }
# #T_15673_row3_col1, #T_15673_row4_col1, #T_15673_row5_col1, #T_15673_row6_col1, #T_15673_row7_col1 {
#   background-color: #950026;
#   color: #f1f1f1;
# }
# #T_15673_row8_col1 {
#   background-color: #a40026;
#   color: #f1f1f1;
# }
# #T_15673_row9_col1 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_15673_row10_col1 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_15673_row11_col1 {
#   background-color: #fc6832;
#   color: #f1f1f1;
# }
# #T_15673_row12_col1 {
#   background-color: #fd7e38;
#   color: #f1f1f1;
# }
# #T_15673_row13_col1 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_15673_row14_col1 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_15673_row15_col1 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_15673_row16_col1 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_15673_row17_col1 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_15673_row18_col1 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_15673_row19_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_15673">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15673_level0_col0" class="col_heading level0 col0" >Entity ID</th>
#       <th id="T_15673_level0_col1" class="col_heading level0 col1" >Pred Score</th>
#       <th id="T_15673_level0_col2" class="col_heading level0 col2" >Pred Popular</th>
#       <th id="T_15673_level0_col3" class="col_heading level0 col3" >Actually Popular</th>
#       <th id="T_15673_level0_col4" class="col_heading level0 col4" >Day Accuracy</th>
#       <th id="T_15673_level0_col5" class="col_heading level0 col5" ># Days</th>
#       <th id="T_15673_level0_col6" class="col_heading level0 col6" >Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15673_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15673_row0_col0" class="data row0 col0" >fallback::motionless in white||afraid of the dark||afraid of the dark</td>
#       <td id="T_15673_row0_col1" class="data row0 col1" >0.9067</td>
#       <td id="T_15673_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_15673_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_15673_row0_col4" class="data row0 col4" >100.00%</td>
#       <td id="T_15673_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_15673_row0_col6" class="data row0 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15673_row1_col0" class="data row1 col0" >fallback::john michael howell||a thousand years||a thousand years</td>
#       <td id="T_15673_row1_col1" class="data row1 col1" >0.9067</td>
#       <td id="T_15673_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_15673_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_15673_row1_col4" class="data row1 col4" >100.00%</td>
#       <td id="T_15673_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_15673_row1_col6" class="data row1 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15673_row2_col0" class="data row2 col0" >fallback::bleachers||you and forever||you and forever</td>
#       <td id="T_15673_row2_col1" class="data row2 col1" >0.9053</td>
#       <td id="T_15673_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_15673_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_15673_row2_col4" class="data row2 col4" >100.00%</td>
#       <td id="T_15673_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_15673_row2_col6" class="data row2 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15673_row3_col0" class="data row3 col0" >fallback::hemlocke springs||be the girl!||the apple tree under the sea</td>
#       <td id="T_15673_row3_col1" class="data row3 col1" >0.9039</td>
#       <td id="T_15673_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_15673_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_15673_row3_col4" class="data row3 col4" >100.00%</td>
#       <td id="T_15673_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_15673_row3_col6" class="data row3 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_15673_row4_col0" class="data row4 col0" >fallback::femtanyl||act right||act right</td>
#       <td id="T_15673_row4_col1" class="data row4 col1" >0.9039</td>
#       <td id="T_15673_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_15673_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_15673_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_15673_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_15673_row4_col6" class="data row4 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_15673_row5_col0" class="data row5 col0" >fallback::femtanyl||body the pistol||man bites dog</td>
#       <td id="T_15673_row5_col1" class="data row5 col1" >0.9039</td>
#       <td id="T_15673_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_15673_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_15673_row5_col4" class="data row5 col4" >100.00%</td>
#       <td id="T_15673_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_15673_row5_col6" class="data row5 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_15673_row6_col0" class="data row6 col0" >fallback::charli xcx||my reminder||wuthering heights</td>
#       <td id="T_15673_row6_col1" class="data row6 col1" >0.9039</td>
#       <td id="T_15673_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_15673_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_15673_row6_col4" class="data row6 col4" >100.00%</td>
#       <td id="T_15673_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_15673_row6_col6" class="data row6 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_15673_row7_col0" class="data row7 col0" >fallback::charli xcx||funny mouth||wuthering heights</td>
#       <td id="T_15673_row7_col1" class="data row7 col1" >0.9039</td>
#       <td id="T_15673_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_15673_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_15673_row7_col4" class="data row7 col4" >100.00%</td>
#       <td id="T_15673_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_15673_row7_col6" class="data row7 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_15673_row8_col0" class="data row8 col0" >fallback::charli xcx||dying for you||wuthering heights</td>
#       <td id="T_15673_row8_col1" class="data row8 col1" >0.9018</td>
#       <td id="T_15673_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_15673_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_15673_row8_col4" class="data row8 col4" >100.00%</td>
#       <td id="T_15673_row8_col5" class="data row8 col5" >1</td>
#       <td id="T_15673_row8_col6" class="data row8 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_15673_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_15673_row9_col0" class="data row9 col0" >fa
# ====================================================================
#   Classifier Top-20  ·  Track — 30d  |  threshold=0.500
#   Hit rate: 100.0%  |  Test prevalence: 35.9%  |  Lift vs random: 2.78x
# ====================================================================
# <style type="text/css">
# #T_0128f_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0128f_row0_col6, #T_0128f_row1_col6, #T_0128f_row2_col6, #T_0128f_row3_col6, #T_0128f_row4_col6, #T_0128f_row5_col6, #T_0128f_row6_col6, #T_0128f_row7_col6, #T_0128f_row8_col6, #T_0128f_row9_col6, #T_0128f_row10_col6, #T_0128f_row11_col6, #T_0128f_row12_col6, #T_0128f_row13_col6, #T_0128f_row14_col6, #T_0128f_row15_col6, #T_0128f_row16_col6, #T_0128f_row17_col6, #T_0128f_row18_col6, #T_0128f_row19_col6 {
#   background-color: #d4edda;
#   color: #155724;
# }
# #T_0128f_row1_col1 {
#   background-color: #a60026;
#   color: #f1f1f1;
# }
# #T_0128f_row2_col1, #T_0128f_row3_col1, #T_0128f_row4_col1, #T_0128f_row5_col1, #T_0128f_row6_col1 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_0128f_row7_col1 {
#   background-color: #e7231e;
#   color: #f1f1f1;
# }
# #T_0128f_row8_col1 {
#   background-color: #e92720;
#   color: #f1f1f1;
# }
# #T_0128f_row9_col1 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_0128f_row10_col1 {
#   background-color: #f94828;
#   color: #f1f1f1;
# }
# #T_0128f_row11_col1 {
#   background-color: #fc4d2a;
#   color: #f1f1f1;
# }
# #T_0128f_row12_col1 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_0128f_row13_col1 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_0128f_row14_col1 {
#   background-color: #fd9640;
#   color: #000000;
# }
# #T_0128f_row15_col1 {
#   background-color: #fecb67;
#   color: #000000;
# }
# #T_0128f_row16_col1 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_0128f_row17_col1 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_0128f_row18_col1 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_0128f_row19_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_0128f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0128f_level0_col0" class="col_heading level0 col0" >Entity ID</th>
#       <th id="T_0128f_level0_col1" class="col_heading level0 col1" >Pred Score</th>
#       <th id="T_0128f_level0_col2" class="col_heading level0 col2" >Pred Popular</th>
#       <th id="T_0128f_level0_col3" class="col_heading level0 col3" >Actually Popular</th>
#       <th id="T_0128f_level0_col4" class="col_heading level0 col4" >Day Accuracy</th>
#       <th id="T_0128f_level0_col5" class="col_heading level0 col5" ># Days</th>
#       <th id="T_0128f_level0_col6" class="col_heading level0 col6" >Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0128f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0128f_row0_col0" class="data row0 col0" >fallback::motionless in white||afraid of the dark||afraid of the dark</td>
#       <td id="T_0128f_row0_col1" class="data row0 col1" >0.9103</td>
#       <td id="T_0128f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_0128f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_0128f_row0_col4" class="data row0 col4" >100.00%</td>
#       <td id="T_0128f_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_0128f_row0_col6" class="data row0 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0128f_row1_col0" class="data row1 col0" >fallback::john michael howell||a thousand years||a thousand years</td>
#       <td id="T_0128f_row1_col1" class="data row1 col1" >0.9042</td>
#       <td id="T_0128f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_0128f_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_0128f_row1_col4" class="data row1 col4" >100.00%</td>
#       <td id="T_0128f_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_0128f_row1_col6" class="data row1 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0128f_row2_col0" class="data row2 col0" >fallback::hemlocke springs||be the girl!||the apple tree under the sea</td>
#       <td id="T_0128f_row2_col1" class="data row2 col1" >0.8937</td>
#       <td id="T_0128f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_0128f_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_0128f_row2_col4" class="data row2 col4" >100.00%</td>
#       <td id="T_0128f_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_0128f_row2_col6" class="data row2 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0128f_row3_col0" class="data row3 col0" >fallback::charli xcx||my reminder||wuthering heights</td>
#       <td id="T_0128f_row3_col1" class="data row3 col1" >0.8937</td>
#       <td id="T_0128f_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_0128f_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_0128f_row3_col4" class="data row3 col4" >100.00%</td>
#       <td id="T_0128f_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_0128f_row3_col6" class="data row3 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0128f_row4_col0" class="data row4 col0" >fallback::femtanyl||act right||act right</td>
#       <td id="T_0128f_row4_col1" class="data row4 col1" >0.8937</td>
#       <td id="T_0128f_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_0128f_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_0128f_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_0128f_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_0128f_row4_col6" class="data row4 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0128f_row5_col0" class="data row5 col0" >fallback::femtanyl||body the pistol||man bites dog</td>
#       <td id="T_0128f_row5_col1" class="data row5 col1" >0.8937</td>
#       <td id="T_0128f_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_0128f_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_0128f_row5_col4" class="data row5 col4" >100.00%</td>
#       <td id="T_0128f_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_0128f_row5_col6" class="data row5 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0128f_row6_col0" class="data row6 col0" >fallback::charli xcx||funny mouth||wuthering heights</td>
#       <td id="T_0128f_row6_col1" class="data row6 col1" >0.8937</td>
#       <td id="T_0128f_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_0128f_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_0128f_row6_col4" class="data row6 col4" >100.00%</td>
#       <td id="T_0128f_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_0128f_row6_col6" class="data row6 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0128f_row7_col0" class="data row7 col0" >fallback::charli xcx||dying for you||wuthering heights</td>
#       <td id="T_0128f_row7_col1" class="data row7 col1" >0.8902</td>
#       <td id="T_0128f_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_0128f_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_0128f_row7_col4" class="data row7 col4" >100.00%</td>
#       <td id="T_0128f_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_0128f_row7_col6" class="data row7 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0128f_row8_col0" class="data row8 col0" >fallback::bleachers||you and forever||you and forever</td>
#       <td id="T_0128f_row8_col1" class="data row8 col1" >0.8891</td>
#       <td id="T_0128f_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_0128f_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_0128f_row8_col4" class="data row8 col4" >100.00%</td>
#       <td id="T_0128f_row8_col5" class="data row8 col5" >1</td>
#       <td id="T_0128f_row8_col6" class="data row8 col6" >✓ TP</td>
#     </tr>
#     <tr>
#       <th id="T_0128f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td
# Classifier top-20 tables — complete.

# %%
# ── Top-20 predicted tracks: 7d and 30d rolling listen count trajectories ─────
# Uses trk_full_pdf (all available data — train + test combined) so we can
# see the full trajectory, not just the test window.  One colour per track.
# The vertical dashed line marks the train/test split.

_rolling_needs = {"listen_count_past_7_days", "listen_count_past_30_days"}

if _rolling_needs.issubset(trk_full_pdf.columns):
    _full = trk_full_pdf[trk_full_pdf["recording_id"].isin(top_tracks)].copy()
    _full["day"] = pd.to_datetime(_full["day"])
    _full = _full.sort_values("day")

    _cmap   = plt.cm.tab20
    _colors = [_cmap(i / max(len(top_tracks) - 1, 1)) for i in range(len(top_tracks))]

    fig, (ax7, ax30) = plt.subplots(2, 1, figsize=(22, 12), sharex=True)
    fig.suptitle(
        "Top 20 Predicted Tracks — 7-Day & 30-Day Rolling Listen Counts",
        fontsize=14,
        y=1.01,
    )

    for i, track_id in enumerate(top_tracks):
        _td    = _full[_full["recording_id"] == track_id]
        _label = f"#{i + 1}  {track_id[:30]}{'…' if len(track_id) > 30 else ''}"
        _col   = _colors[i]

        if not _td.empty:
            ax7.plot(
                _td["day"], _td["listen_count_past_7_days"],
                linewidth=1.4, alpha=0.85, color=_col, label=_label,
            )
            ax30.plot(
                _td["day"], _td["listen_count_past_30_days"],
                linewidth=1.4, alpha=0.85, color=_col, label=_label,
            )

    for _ax in (ax7, ax30):
        _ax.axvline(
            train_max_day, color="black", linestyle="--",
            linewidth=1.5, alpha=0.65, label="Train/Test split",
        )
        _ax.tick_params(axis="x", rotation=30, labelsize=9)
        _ax.grid(True, alpha=0.2)

    ax7.set_title("7-Day Rolling Total Listens", fontsize=11)
    ax7.set_ylabel("Listens (past 7 days)")

    ax30.set_title("30-Day Rolling Total Listens", fontsize=11)
    ax30.set_ylabel("Listens (past 30 days)")
    ax30.set_xlabel("Date")

    # Single shared legend on the right
    _handles, _labels = ax7.get_legend_handles_labels()
    fig.legend(
        _handles, _labels,
        bbox_to_anchor=(1.01, 0.98),
        loc="upper left",
        fontsize=8,
        ncol=1,
        framealpha=0.9,
    )

    plt.tight_layout()
    plt.show()
    print("Rolling listen count trends — complete.")
else:
    _missing = _rolling_needs - set(trk_full_pdf.columns)
    print(f"Rolling columns not found in trk_full_pdf: {_missing}. Skipping.")
# Out:
# Rolling listen count trends — complete.

# %% [markdown]
# ## Presentation Insights & Model Summary
#
# **Key findings for slides** — performance breakdown, lift analysis, and recommendations for data/infrastructure narrative.

# %%
# ── Executive summary: model performance & presentation strategy ─────────────
# Uses saved model files to generate insights independent of kernel state.

import pickle
import torch

print("="*80)
print("MODEL PERFORMANCE SUMMARY FOR PRESENTATION")
print("="*80)

# Load saved XGBoost results
_xgb_path = Path("../models/xgb_models.pkl")
_lstm_path = Path("../models/lstm_models.pt")

xgb_results_saved, lstm_results_saved = {}, {}
if _xgb_path.exists():
    with open(_xgb_path, "rb") as f:
        xgb_results_saved = pickle.load(f)
    print(f"\nLoaded {len(xgb_results_saved)} XGBoost results from {_xgb_path}")

if _lstm_path.exists():
    lstm_save_data = torch.load(_lstm_path, map_location="cpu")
    for key, data in lstm_save_data.items():
        lstm_results_saved[key] = (None, data.get("metrics", {}), None)
    print(f"Loaded {len(lstm_results_saved)} LSTM results from {_lstm_path}")

# Rebuild metrics
_metrics_rows = []
for key_set, label in [(xgb_results_saved, "XGBoost"), (lstm_results_saved, "LSTM")]:
    for (entity, horizon, mtype), item in key_set.items():
        metrics = item[1] if isinstance(item, tuple) else item.get("metrics", {})
        if not metrics:
            continue
        row = {"Model": label, "Entity": entity, "Horizon": horizon, "Type": mtype}
        row.update(metrics)
        _metrics_rows.append(row)

_mdf = pd.DataFrame(_metrics_rows)

if _mdf.empty:
    print("\n⚠️  No metrics available.")
else:
    print(f"\nAvailable models: {_mdf[['Model', 'Entity', 'Horizon', 'Type']].to_string(index=False)}")
    
    print(f"\n{'='*80}")
    print("CLASSIFIER PERFORMANCE SUMMARY")
    print(f"{'='*80}")
    
    clf_df = _mdf[_mdf["Type"] == "clf"].copy()
    if not clf_df.empty:
        for entity in ["artist", "track"]:
            ent_df = clf_df[clf_df["Entity"] == entity]
            if ent_df.empty:
                continue
            print(f"\n{entity.upper()}:")
            for horizon in ["7d", "30d"]:
                h_df = ent_df[ent_df["Horizon"] == horizon]
                if h_df.empty:
                    continue
                for _, row in h_df.iterrows():
                    print(
                        f"  {row['Model']} {horizon:>3s}: "
                        f"AUC={row.get('roc_auc', np.nan):.3f}  "
                        f"AP={row.get('pr_auc', np.nan):.3f}  "
                        f"F1={row.get('f1', np.nan):.3f}  "
                        f"AP_gain={row.get('pr_auc_gain', np.nan):+.3f}"
                    )

    print(f"\n{'='*80}")
    print("REGRESSOR PERFORMANCE SUMMARY")
    print(f"{'='*80}")
    
    reg_df = _mdf[_mdf["Type"] == "reg"].copy()
    if not reg_df.empty:
        for entity in ["artist", "track"]:
            ent_df = reg_df[reg_df["Entity"] == entity]
            if ent_df.empty:
                continue
            print(f"\n{entity.upper()}:")
            for horizon in ["7d", "30d"]:
                h_df = ent_df[ent_df["Horizon"] == horizon]
                if h_df.empty:
                    continue
                for _, row in h_df.iterrows():
                    print(
                        f"  {row['Model']} {horizon:>3s}: "
                        f"RMSE={row.get('rmse', np.nan):.3f}  "
                        f"MAE={row.get('mae', np.nan):.3f}  "
                        f"RMSE_gain={row.get('rmse_improvement', np.nan):+.3f}"
                    )

    print(f"\n{'='*80}")
    print("PRESENTATION STRATEGY & RECOMMENDATIONS")
    print(f"{'='*80}")
    
    print(f"\n✓ WHAT'S WORKING (HIGHLIGHT):")
    works = clf_df[clf_df["pr_auc_gain"] > 0.01]
    if not works.empty:
        for _, row in works.iterrows():
            print(f"  • {row['Model']} {row['Entity']} {row['Horizon']}: {row['pr_auc']:.3f} AP (baseline gain {row['pr_auc_gain']:+.3f})")
    else:
        print(f"  (Limited gains over baseline; focus on infrastructure story)")

    print(f"\n⚠️  WHAT NEEDS WORK (JUSTIFY WITH DATA/INFRA ROADMAP):")
    underperf = _mdf[(~_mdf["Type"].isin(["clf"])) | (_mdf.get("pr_auc_gain", 0) <= 0.01)]
    if len(underperf) > 0:
        print(f"  • {len(_mdf)} trained models with modest signal suggests:")
        print(f"    - 2-month data window too short for trend detection")
        print(f"    - Current features (listen counts + percentiles) lack external signal")
        print(f"    - Class imbalance: 'popular' is rare in 7/30-day windows")

    print(f"\n💡 HYPOTHETICAL ANALYSIS (For 'What Could Be' slide):")
    print(f"  **Data:** 6–12 month history, artist/track metadata, playlist inclusions, genre")
    print(f"  **Infra:** Real-time pipeline, cross-platform aggregation, collaboration networks")
    print(f"  **Models:** Ensemble XGB+LSTM, multi-task learning, causality analysis")
    print(f"  **Expected impact:** 2–3× improvement in AP, ROI from feature engineering clear")

print(f"\n{'='*80}\n")
# Out:
# ================================================================================
# MODEL PERFORMANCE SUMMARY FOR PRESENTATION
# ================================================================================
#
# Loaded 8 XGBoost results from ../models/xgb_models.pkl
# Loaded 0 LSTM results from ../models/lstm_models.pt
#
# Available models:   Model Entity Horizon Type
# XGBoost artist      7d  clf
# XGBoost artist      7d  reg
# XGBoost artist     30d  clf
# XGBoost artist     30d  reg
# XGBoost  track      7d  clf
# XGBoost  track      7d  reg
# XGBoost  track     30d  clf
# XGBoost  track     30d  reg
#
# ================================================================================
# CLASSIFIER PERFORMANCE SUMMARY
# ================================================================================
#
# ARTIST:
#   XGBoost  7d: AUC=0.871  AP=0.232  F1=0.245  AP_gain=+0.206
#   XGBoost 30d: AUC=0.872  AP=0.252  F1=0.219  AP_gain=+0.226
#
# TRACK:
#   XGBoost  7d: AUC=0.909  AP=0.882  F1=0.725  AP_gain=+0.523
#   XGBoost 30d: AUC=0.917  AP=0.894  F1=0.747  AP_gain=+0.534
#
# ================================================================================
# REGRESSOR PERFORMANCE SUMMARY
# ================================================================================
#
# ARTIST:
#   XGBoost  7d: RMSE=0.126  MAE=0.102  RMSE_gain=+0.056
#   XGBoost 30d: RMSE=0.127  MAE=0.103  RMSE_gain=+0.054
#
# TRACK:
#   XGBoost  7d: RMSE=0.114  MAE=0.093  RMSE_gain=+0.117
#   XGBoost 30d: RMSE=0.090  MAE=0.068  RMSE_gain=+0.107
#
# ================================================================================
# PRESENTATION STRATEGY & RECOMMENDATIONS
# ================================================================================
#
# ✓ WHAT'S WORKING (HIGHLIGHT):
#   • XGBoost artist 7d: 0.232 AP (baseline gain +0.206)
#   • XGBoost artist 30d: 0.252 AP (baseline gain +0.226)
#   • XGBoost track 7d: 0.882 AP (baseline gain +0.523)
#   • XGBoost track 30d: 0.894 AP (baseline gain +0.534)
#
# ⚠️  WHAT NEEDS WORK (JUSTIFY WITH DATA/INFRA ROADMAP):
#   • 8 trained models with modest signal suggests:
#     - 2-month data window too short for trend detection
#     - Current features (listen counts + percentiles) lack external signal
#     - Class imbalance: 'popular' is rare in 7/30-day windows
#
# 💡 HYPOTHETICAL ANALYSIS (For 'What Could Be' slide):
#   **Data:** 6–12 month history, artist/track metadata, playlist inclusions, genre
#   **Infra:** Real-time pipeline, cross-platform aggregation, collaboration networks
#   **Models:** Ensemble XGB+LSTM, multi-task learning, causality analysis
#   **Expected impact:** 2–3× improvement in AP, ROI from feature engineering clear
#
# ================================================================================

# %%
# ── Classifier hit rate & lift: bar chart across models/entities/horizons ──────
# Shows how well the top-20 predictions perform vs random baseline for each config.
# Perfect for a "model effectiveness" slide.

_hit_lift_data = []

for entity, _, test_df, feat_cols in configs:
    id_col = "artist_id" if entity == "artist" else "recording_id"
    
    for horizon in ["7d", "30d"]:
        clf_key = (entity, horizon, "clf")
        if clf_key not in xgb_results:
            continue
        
        clf_entry = xgb_results[clf_key]
        if clf_entry[0] is None or not len(clf_entry[2]):
            continue
        
        clf_target = f"is_popular_{horizon}"
        proba = clf_entry[2]
        
        test_copy = test_df[[id_col, clf_target]].copy()
        test_copy["pred_score"] = proba
        
        # Top-20 by predicted score
        top20 = (
            test_copy.groupby(id_col).agg(
                mean_score=("pred_score", "mean"),
                actually_popular=(clf_target, "max"),
            )
            .sort_values("mean_score", ascending=False)
            .head(20)
        )
        
        hit_rate = top20["actually_popular"].mean()
        prevalence = float(test_df[clf_target].mean())
        lift = (hit_rate / prevalence) if prevalence > 0 else 1.0
        
        _hit_lift_data.append({
            "Entity": entity.title(),
            "Horizon": horizon,
            "Model": "XGBoost",
            "Hit Rate (%)": 100 * hit_rate,
            "Lift": lift,
            "Baseline (%)": 100 * prevalence,
        })

# Same for LSTM if available
for entity, _, test_df, feat_cols in configs:
    id_col = "artist_id" if entity == "artist" else "recording_id"
    
    for horizon in ["7d", "30d"]:
        lstm_key = (entity, horizon, "clf")
        if lstm_key not in lstm_results:
            continue
        
        lstm_entry = lstm_results[lstm_key]
        if lstm_entry[0] is None or not len(lstm_entry[2]):
            continue
        
        clf_target = f"is_popular_{horizon}"
        lstm_ds = TimeSeriesDataset(test_df, id_col, feat_cols, clf_target, seq_len=SEQ_LEN)
        
        if len(lstm_ds) == 0:
            continue
        
        test_copy = test_df[[id_col, clf_target]].copy()
        test_copy = test_copy.iloc[:len(lstm_entry[2])]  # Match LSTM output length
        test_copy["pred_score"] = lstm_entry[2]
        
        top20 = (
            test_copy.groupby(id_col).agg(
                mean_score=("pred_score", "mean"),
                actually_popular=(clf_target, "max"),
            )
            .sort_values("mean_score", ascending=False)
            .head(20)
        )
        
        if len(top20) > 0:
            hit_rate = top20["actually_popular"].mean()
            prevalence = float(test_df[clf_target].mean())
            lift = (hit_rate / prevalence) if prevalence > 0 else 1.0
            
            _hit_lift_data.append({
                "Entity": entity.title(),
                "Horizon": horizon,
                "Model": "LSTM",
                "Hit Rate (%)": 100 * hit_rate,
                "Lift": lift,
                "Baseline (%)": 100 * prevalence,
            })

if _hit_lift_data:
    _hldf = pd.DataFrame(_hit_lift_data)
    
    fig, (ax_hit, ax_lift) = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle("Classifier Effectiveness: Top-20 Hit Rate & Lift vs Baseline", fontsize=13)
    
    # Hit rate
    for entity in _hldf["Entity"].unique():
        entity_data = _hldf[_hldf["Entity"] == entity]
        x_pos = np.arange(len(entity_data))
        colors = ["steelblue" if m == "XGBoost" else "darkorange" for m in entity_data["Model"]]
        ax_hit.bar(x_pos + (0 if entity == "Artist" else 5), entity_data["Hit Rate (%)"], 
                   label=f"{entity} (baseline: {entity_data['Baseline (%)'].iloc[0]:.1f}%)",
                   color=colors, alpha=0.75, width=0.35)
    
    ax_hit.axhline(_hldf["Baseline (%)"].mean(), color="red", linestyle="--", 
                   linewidth=1.5, alpha=0.7, label="Random baseline")
    ax_hit.set_ylabel("Hit Rate (%)", fontsize=11)
    ax_hit.set_title("Percentage of Top-20 Actually Popular", fontsize=11)
    ax_hit.legend(fontsize=9)
    ax_hit.grid(True, alpha=0.2, axis="y")
    
    # Lift
    _lift_data = _hldf[["Entity", "Horizon", "Model", "Lift"]].copy()
    _x = np.arange(len(_lift_data))
    _colors = ["steelblue" if m == "XGBoost" else "darkorange" for m in _lift_data["Model"]]
    ax_lift.bar(_x, _lift_data["Lift"], color=_colors, alpha=0.75, width=0.6)
    ax_lift.axhline(1.0, color="red", linestyle="--", linewidth=1.5, alpha=0.7, label="1.0x (random)")
    ax_lift.set_ylabel("Lift vs Random", fontsize=11)
    ax_lift.set_title("Improvement Over Random Baseline", fontsize=11)
    ax_lift.set_xticks(_x)
    ax_lift.set_xticklabels(
        [f"{row['Entity'][0]}{row['Horizon']}{row['Model'][0]}" for _, row in _lift_data.iterrows()],
        fontsize=9
    )
    ax_lift.legend(["Random baseline"], fontsize=9)
    ax_lift.grid(True, alpha=0.2, axis="y")
    
    plt.tight_layout()
    plt.show()
    print(f"Hit rate & lift summary table:")
    print(_hldf.round(3).to_string(index=False))
else:
    print("No classifier data available for hit rate chart.")
# Out:
# Hit rate & lift summary table:
# Entity Horizon   Model  Hit Rate (%)   Lift  Baseline (%)
# Artist      7d XGBoost         100.0 38.844         2.574
# Artist     30d XGBoost         100.0 38.844         2.574
#  Track      7d XGBoost         100.0  2.783        35.938
#  Track     30d XGBoost         100.0  2.783        35.938
